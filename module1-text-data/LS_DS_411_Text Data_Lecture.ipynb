# %% [markdown]
# Lambda School Data Science
#
# *Unit 4, Sprint 1, Module 1*
#
# ---
# <h1 id="moduleTitle"> Natural Language Processing Introduction (Prepare)</h1>
#
# "Natural" meaning - not computer languages but spoken/written human languages. The hard thing about NLP is that human languages are far less structured or consistent than computer languages. This is perhaps the largest source of difficulty when trying to get computers to "understand" human languages. How do you get a machine to understand sarcasm, and irony, and synonyms, connotation, denotation, nuance, and tone of voice --all without it having lived a lifetime of experience for context? If you think about it, our human brains have been exposed to quite a lot of training data to help us interpret languages, and even then we misunderstand each other pretty frequently.
#
#
# <h2 id='moduleObjectives'>Learning Objectives</h2>
#
# By the end of end of this module, a student should be able to:
# * <a href="#p1">Objective 1</a>: Tokenize text
# * <a href="#p1">Objective 2</a>: Remove stop words from text
# * <a href="#p3">Objective 3</a>: Perform stemming and lemmatization on tokens
#
# ## Conda Environments
#
# You will be completing each module this sprint on your machine. We will be using conda environments to manage the packages and their dependencies for this sprint's content. In a classroom setting, instructors typically abstract away environment for you. However, environment management is an important professional data science skill. We showed you how to manage environments using pipvirtual env during Unit 3, but in this sprint, we will introduce an environment management tool common in the data science community:
#
# > __conda__: Package, dependency and environment management for any language—Python, R, Ruby, Lua, Scala, Java, JavaScript, C/ C++, FORTRAN, and more.
#
# The easiest way to install conda on your machine is via the [Anaconda Distribution](https://www.anaconda.com/distribution/) of Python & R. Once you have conda installed, read ["A Guide to Conda Environments"](https://towardsdatascience.com/a-guide-to-conda-environments-bc6180fc533). This article will provide an introduce into some of the conda basics. If you need some additional help getting started, the official ["Setting started with conda"](https://conda.io/projects/conda/en/latest/user-guide/getting-started.html) guide will point you in the right direction.
#
# :snake:
#
# To get the sprint environment setup:
#
# 1. Open your command line tool (Terminal for MacOS, Anaconda Prompt for Windows)
# 2. Navigate to the folder with this sprint's content. There should be a `requirements.txt`
# 3. Run `conda create -n U4-S1-NLP python==3.7` => You can also rename the environment if you would like. Once the command completes, your conda environment should be ready.
# 4. Now, we are going to add in the require python packages for this sprint. You will need to 'activate' the conda environment: `source activate U4-S1-NLP` on Terminal or `conda activate U4-S1-NLP` on Anaconda Prompt. Once your environment is activate, run `pip install -r requirements.txt` which will install the required packages into your environment.
# 5. We are going to also add an Ipython Kernel reference to your conda environment, so we can use it from JupyterLab.
# 6. Next run `python -m ipykernel install --user --name U4-S1-NLP --display-name "U4-S1-NLP (Python3)"` => This will add a json object to an ipython file, so JupterLab will know that it can use this isolated instance of Python. :)
# 7. Last step, we need to install the models for Spacy. Run these commands `python -m spacy download en_core_web_md` and `python -m spacy download en_core_web_lg`
# 8. Deactivate your conda environment and launch JupyterLab. You should know see "U4-S1-NLP (Python3)" in the list of available kernels on launch screen.

# %% [markdown]
# # Tokenze Text (Learn)
# <a id="p1"></a>

# %% [markdown]
# ## Overview
#
# > **token**: an instance of a sequence of characters in some particular document that are grouped together as a useful semantic unit for processing
#
# > [_*Introduction to Information Retrival*_](https://nlp.stanford.edu/IR-book/)
#
#
# ### The attributes of good tokens
#
# * Should be stored in an iterable data structure
#   - Allows analysis of the "semantic unit"
# * Should be all the same case
#   - Reduces the complexity of our data
# * Should be free of non-alphanumeric characters (ie punctuation, whitespace)
#   - Removes information that is probably not relevant to the analysis

# %% [markdown]
# Let's pretend we are trying analyze the random sequence here. Question: what is the most common character in this sequence?

# %%
random_seq = "AABAAFBBBBCGCDDEEEFCFFDFFAFFZFGGGGHEAFJAAZBBFCZ"

# %% [markdown]
# A useful unit of analysis for us is going to be a letter or character

# %%
tokens = list(random_seq)
print(tokens)
# Out:
# ['A', 'A', 'B', 'A', 'A', 'F', 'B', 'B', 'B', 'B', 'C', 'G', 'C', 'D', 'D', 'E', 'E', 'E', 'F', 'C', 'F', 'F', 'D', 'F', 'F', 'A', 'F', 'F', 'Z', 'F', 'G', 'G', 'G', 'G', 'H', 'E', 'A', 'F', 'J', 'A', 'A', 'Z', 'B', 'B', 'F', 'C', 'Z']

# %% [markdown]
# Our tokens are already "good": in an iterable datastructure, all the same case, and free of noise characters (punctuation, whitespace), so we can jump straight into analysis.

# %%
import seaborn as sns

sns.countplot(tokens);

# %% [markdown]
# The most common character in our sequence is  "F". We can't just glance at the the sequence to know which character is the most common. We (humans) struggle to subitize complex data (like random text sequences).
#
# > __Subitize__ is the ability to tell the number of objects in a set, quickly, without counting.
#
# We need to chunk the data into countable pieces "tokens" for us to analyze them. This inability subitize text data is the motivation for our discussion today.

# %% [markdown]
# ### Tokenizing with Pure Python

# %%
sample = "Friends, Romans, countrymen, lend me your ears;"

# %% [markdown]
# ##### Iterable Tokens
#
# A string object in Python is already iterable. However, the item you iterate over is a character not a token:
#
# ```
# from time import sleep
# for num, character in enumerate(sample):
#     sleep(.5)
#     print(f"Char {num} - {character}", end="\r")
# ```
#
# If we instead care about the words in our sample (our semantic unit), we can use the string method `.split()` to separate the whitespace and create iterable units. :)

# %%
sample.split(",")
# Out:
# ['Friends', ' Romans', ' countrymen', ' lend me your ears;']

# %% [markdown]
# ##### Case Normalization
# A common data cleaning data cleaning task with token is to standardize or normalize the case. Normalizing case reduces the chance that you have duplicate records for things which have practically the same semantic meaning. You can use either the `.lower()` or `.upper()` string methods to normalize case.
#
# Consider the following example:

# %%
import zipfile
import pandas as pd
zf = zipfile.ZipFile('./data/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv.zip') 
df = pd.read_csv(zf.open('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv'))

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 3  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 4  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 3  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 4  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 2   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 3   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 4   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 2  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 3  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 4  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
# 1                 NaN        NaN                NaN              4
# 2                 NaN        NaN                NaN              5
# 3                 NaN        NaN                NaN              5
# 4                 NaN        NaN                NaN              5
#
#                                   reviews.sourceURLs  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
# 2  https://www.amazon.com/product-reviews/B00QWO9...
# 3  https://www.amazon.com/product-reviews/B00QWO9...
# 4  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
# 2  ... are not Duracell but for the price i am ha...  BySharon Lambert
# 3  ... as well as name brand batteries at a much ...     Bymark sexson
# 4  ... batteries are very long lasting the price ...           Bylinda
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
# 2  https://www.barcodable.com/upc/841710106442,ht...
# 3  https://www.barcodable.com/upc/841710106442,ht...
# 4  https://www.barcodable.com/upc/841710106442,ht...
#
# [5 rows x 24 columns]

# %%
# Notice anything odd here? 
df['brand'].value_counts()
# Out:
# Amazon          16153
# Amazonbasics    12169
# AmazonBasics       10
# Name: brand, dtype: int64

# %%
# Much cleaner
df['brand'] = df['brand'].apply(lambda x: x.lower())
df['brand'].value_counts()
# Out:
# amazon          16153
# amazonbasics    12179
# Name: brand, dtype: int64

# %% [markdown]
# ##### Keep Only Alphanumeric Characters
# Yes, we only want letters and numbers. Everything else is probably noise: punctuation, whitespace, and other notation. This one is little bit more complicated than our previous example. Here we will have to import the base package `re` (regular expressions).
#
# The only regex expression pattern you need for this is `'[^a-zA-Z 0-9]'` which keeps lower case letters, upper case letters, spaces, and numbers.

# %%
sample = sample+" 911"
print(sample)
# Out:
# Friends, Romans, countrymen, lend me your ears; 911

# %%
import re

re.sub('[^a-zA-Z 0-9]', '', sample)
# Out:
# 'Friends Romans countrymen lend me your ears 911'

# %% [markdown]
# #### Two Minute Challenge
# - Complete the function `tokenize` below
# - Combine the methods which we discussed above to clean text before we analyze it
# - You can put the methods in any order you want

# %%
def tokenize(text):
    """Parses a string into a list of semantic units (words)

    Args:
        text (str): The string that the function will tokenize.

    Returns:
        list: tokens parsed out by the mechanics of your choice
    """
    
    tokens = re.sub('[^a-zA-Z 0-9]', '', text)
    tokens = tokens.lower().split()
    
    return tokens

# %%
tokenize(sample)
# Out:
# ['friends', 'romans', 'countrymen', 'lend', 'me', 'your', 'ears', '911']

# %% [markdown]
# ## Follow Along
#
# Our inability to analyze text data becomes quickly amplified in a business context. Consider the following:
#
# A business which sells widgets also collects customer reviews of those widgets. When the business first started out, they had a human read the reviews to look for patterns. Now, the business sells thousands of widgets a month. The human readers can't keep up with the pace of reviews to synthesize an accurate analysis. They need some science to help them analyze their data.
#
# Now, let's pretend that business is Amazon, and the widgets are Amazon products such as the Alexa, Echo, or other AmazonBasics products. Let's analyze their reviews with some counts. This dataset is available on [Kaggle](https://www.kaggle.com/datafiniti/consumer-reviews-of-amazon-products/).

# %%
"""
Import Statements
"""

# Base
from collections import Counter
import re
 
import pandas as pd

# Plotting
import squarify
import matplotlib.pyplot as plt
import seaborn as sns

# NLP Libraries
import spacy
from spacy.tokenizer import Tokenizer
from nltk.stem import PorterStemmer

nlp = spacy.load("en_core_web_lg")

# %%
df.head(2)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# 0   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
# 1   Health & Beauty  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys  ... reviews.didPurchase  \
# 0  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
# 1  amazonbasics/hl002619,amazonbasicsaaaperforman...  ...                 NaN
#
#   reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 0                 NaN        NaN                NaN              3
# 1                 NaN        NaN                NaN              4
#
#                                   reviews.sourceURLs  \
# 0  https://www.amazon.com/product-reviews/B00QWO9...
# 1  https://www.amazon.com/product-reviews/B00QWO9...
#
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
#
#                                        reviews.title  reviews.username  \
# 0  ... 3 of them and one of the item is bad quali...        Byger yang
# 1  ... always the less expensive way to go for pr...              ByMG
#
#                                           sourceURLs
# 0  https://www.barcodable.com/upc/841710106442,ht...
# 1  https://www.barcodable.com/upc/841710106442,ht...
#
# [2 rows x 24 columns]

# %%
df.shape
# Out:
# (28332, 24)

# %%
# How can we count the raw text?
df['reviews.text'].value_counts(normalize=True)[:50]
# Out:
# good                0.002118
# great               0.001729
# Good                0.001482
# Great               0.001341
# ok                  0.001165
# Great price         0.001059
# great price         0.000988
# Excellent           0.000988
# Great value         0.000953
# good price          0.000812
# great value         0.000777
# Great price!        0.000635
# good value          0.000600
# good deal           0.000565
# Great value.        0.000565
# Great deal          0.000529
# Good deal           0.000529
# As expected         0.000529
# Great product       0.000529
# OK                  0.000529
# Good value          0.000494
# Good batteries      0.000494
# Great value!        0.000459
# great deal          0.000459
# Great batteries.    0.000459
# So far so good      0.000459
# Good price          0.000459
# Good buy            0.000424
# Work great          0.000424
# Great!              0.000388
# excellent           0.000388
# Great buy           0.000388
# as expected         0.000388
# Great batteries     0.000388
# Great deal!         0.000388
# Great price.        0.000388
# good batteries      0.000388
# Good value.         0.000388
# very good           0.000388
# As described        0.000388
# Ok                  0.000353
# Perfect!            0.000353
# great batteries     0.000353
# good product        0.000353
# Nice                0.000353
# Work great.         0.000353
# Very good           0.000318
# Great buy!          0.000318
# Great product.      0.000318
# Long lasting        0.000318
# Name: reviews.text, dtype: float64

# %%
df['tokens'] = df['reviews.text'].apply(tokenize)

# %%
df['tokens'].head()
# Out:
# 0    [i, order, 3, of, them, and, one, of, the, ite...
# 1    [bulk, is, always, the, less, expensive, way, ...
# 2    [well, they, are, not, duracell, but, for, the...
# 3    [seem, to, work, as, well, as, name, brand, ba...
# 4    [these, batteries, are, very, long, lasting, t...
# Name: tokens, dtype: object

# %%
df[['reviews.text', 'tokens']][:10]
# Out:
#                                         reviews.text  \
# 0  I order 3 of them and one of the item is bad q...
# 1  Bulk is always the less expensive way to go fo...
# 2  Well they are not Duracell but for the price i...
# 3  Seem to work as well as name brand batteries a...
# 4  These batteries are very long lasting the pric...
# 5  Bought a lot of batteries for Christmas and th...
# 6  ive not had any problame with these batteries ...
# 7  Well if you are looking for cheap non-recharge...
# 8  These do not hold the amount of high power jui...
# 9  AmazonBasics AA AAA batteries have done well b...
#
#                                               tokens
# 0  [i, order, 3, of, them, and, one, of, the, ite...
# 1  [bulk, is, always, the, less, expensive, way, ...
# 2  [well, they, are, not, duracell, but, for, the...
# 3  [seem, to, work, as, well, as, name, brand, ba...
# 4  [these, batteries, are, very, long, lasting, t...
# 5  [bought, a, lot, of, batteries, for, christmas...
# 6  [ive, not, had, any, problame, with, these, ba...
# 7  [well, if, you, are, looking, for, cheap, nonr...
# 8  [these, do, not, hold, the, amount, of, high, ...
# 9  [amazonbasics, aa, aaa, batteries, have, done,...

# %%
df['primaryCategories'].value_counts()
# Out:
# Electronics                    13995
# Health & Beauty                12071
# Toys & Games,Electronics        1676
# Office Supplies,Electronics      386
# Electronics,Media                185
# Office Supplies                    9
# Animals & Pet Supplies             6
# Home & Garden                      2
# Electronics,Furniture              2
# Name: primaryCategories, dtype: int64

# %%
df = df[df['primaryCategories'] == 'Electronics'].copy()

# %%
df.head()
# Out:
#                         id             dateAdded           dateUpdated  \
# 8343  AVpe7nGV1cnluZ0-aG2o  2014-10-28T11:14:38Z  2019-04-25T09:05:28Z
# 8344  AVpe7nGV1cnluZ0-aG2o  2014-10-28T11:14:38Z  2019-04-25T09:05:28Z
# 8345  AVpe7nGV1cnluZ0-aG2o  2014-10-28T11:14:38Z  2019-04-25T09:05:28Z
# 8346  AVpe7nGV1cnluZ0-aG2o  2014-10-28T11:14:38Z  2019-04-25T09:05:28Z
# 8347  AVpfl8cLLJeJML43AE3S  2016-04-08T18:16:28Z  2019-04-25T08:51:22Z
#
#                                                  name                  asins  \
# 8343  AmazonBasics Nylon CD/DVD Binder (400 Capacity)  B00DIHVMEA,B00EZ1ZTV0
# 8344  AmazonBasics Nylon CD/DVD Binder (400 Capacity)  B00DIHVMEA,B00EZ1ZTV0
# 8345  AmazonBasics Nylon CD/DVD Binder (400 Capacity)  B00DIHVMEA,B00EZ1ZTV0
# 8346  AmazonBasics Nylon CD/DVD Binder (400 Capacity)  B00DIHVMEA,B00EZ1ZTV0
# 8347                            Amazon Echo ‚Äì White  B01E6AO69U,B00L9EPT8O
#
#              brand                                         categories  \
# 8343  amazonbasics  Audio & Video Accessories,TV, Video & Home Aud...
# 8344  amazonbasics  Audio & Video Accessories,TV, Video & Home Aud...
# 8345  amazonbasics  Audio & Video Accessories,TV, Video & Home Aud...
# 8346  amazonbasics  Audio & Video Accessories,TV, Video & Home Aud...
# 8347        amazon  Stereos,Remote Controls,Audio Docks & Mini Spe...
#
#      primaryCategories                                          imageURLs  \
# 8343       Electronics  http://ecx.images-amazon.com/images/I/41jQha7Z...
# 8344       Electronics  http://ecx.images-amazon.com/images/I/41jQha7Z...
# 8345       Electronics  http://ecx.images-amazon.com/images/I/41jQha7Z...
# 8346       Electronics  http://ecx.images-amazon.com/images/I/41jQha7Z...
# 8347       Electronics  https://i.ebayimg.com/images/g/NWEAAOSwDehbdx6...
#
#                                                    keys  ...  \
# 8343  amazonbasicsnyloncddvdbinder400capacity/b00ez1...  ...
# 8344  amazonbasicsnyloncddvdbinder400capacity/b00ez1...  ...
# 8345  amazonbasicsnyloncddvdbinder400capacity/b00ez1...  ...
# 8346  amazonbasicsnyloncddvdbinder400capacity/b00ez1...  ...
# 8347  amazonechowhite/b00l9ept8o,amazonechowhite/b01...  ...
#
#      reviews.doRecommend reviews.id reviews.numHelpful reviews.rating  \
# 8343                 NaN        NaN                NaN              5
# 8344                 NaN        NaN                NaN              5
# 8345                 NaN        NaN                NaN              5
# 8346                 NaN        NaN                NaN              2
# 8347                 NaN        NaN                NaN              5
#
#                                      reviews.sourceURLs  \
# 8343  https://www.ebay.com/itm/Amazonbasics-Nylon-Cd...
# 8344  http://www.amazon.co.uk/gp/product-reviews/B00...
# 8345  https://www.ebay.com/itm/Amazonbasics-Nylon-Cd...
# 8346  http://www.amazon.co.uk/gp/product-reviews/B00...
# 8347  https://www.newegg.com/Product/Product.aspx?It...
#
#                                            reviews.text  \
# 8343  Great case to keep everything in its place! My...
# 8344  After discarding and getting rid of broken cd ...
# 8345     A few dollars more, but I am boycotting amazon
# 8346  My initial impression of this was very good. T...
# 8347  Pros: Standard Echo. Cons: Older generation Ec...
#
#                                           reviews.title  reviews.username  \
# 8343                                  Excellent product           qs341_5
# 8344                       It was a much needed storage          Diablita
# 8345                                    it was worth it  coldbloodblazing
# 8346  Not well designed, very tight when full. Becom...             Snrub
# 8347                              Arrived as described.         Anonymous
#
#                                              sourceURLs  \
# 8343  https://www.ebay.com/itm/AmazonBasics-Nylon-CD...
# 8344  https://www.ebay.com/itm/AmazonBasics-Nylon-CD...
# 8345  https://www.ebay.com/itm/AmazonBasics-Nylon-CD...
# 8346  https://www.ebay.com/itm/AmazonBasics-Nylon-CD...
# 8347  https://www.newegg.com/Product/Product.aspx?It...
#
#                                                  tokens
# 8343  [great, case, to, keep, everything, in, its, p...
# 8344  [after, discarding, and, getting, rid, of, bro...
# 8345  [a, few, dollars, more, but, i, am, boycotting...
# 8346  [my, initial, impression, of, this, was, very,...
# 8347  [pros, standard, echo, cons, older, generation...
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Analyzing Tokens

# %%
# Object from Base Python
from collections import Counter

# The object `Counter` takes an iterable, but you can instaniate an empty one and update it. 
word_counts = Counter()

# Update it based on a split of each of our documents
df['tokens'].apply(lambda x: word_counts.update(x))

# Print out the 10 most common words
word_counts.most_common(10)
# Out:
# [('the', 17723),
#  ('and', 14005),
#  ('it', 13113),
#  ('to', 12750),
#  ('for', 12224),
#  ('i', 12037),
#  ('a', 10494),
#  ('is', 8508),
#  ('this', 8109),
#  ('my', 7914)]

# %% [markdown]
# Let's create a fuction which takes a corpus of document and returns and dataframe of word counts for us to analyze.

# %%
def count(docs):

        word_counts = Counter()
        appears_in = Counter()
        
        total_docs = len(docs)

        for doc in docs:
            word_counts.update(doc)
            appears_in.update(set(doc))

        temp = zip(word_counts.keys(), word_counts.values())
        
        wc = pd.DataFrame(temp, columns = ['word', 'count'])

        wc['rank'] = wc['count'].rank(method='first', ascending=False)
        total = wc['count'].sum()

        wc['pct_total'] = wc['count'].apply(lambda x: x / total)
        
        wc = wc.sort_values(by='rank')
        wc['cul_pct_total'] = wc['pct_total'].cumsum()

        t2 = zip(appears_in.keys(), appears_in.values())
        ac = pd.DataFrame(t2, columns=['word', 'appears_in'])
        wc = ac.merge(wc, on='word')

        wc['appears_in_pct'] = wc['appears_in'].apply(lambda x: x / total_docs)
        
        return wc.sort_values(by='rank')

# %%
# Use the Function
wc = count(df['tokens'])

# %%
wc.head(50)
# Out:
#         word  appears_in  count  rank  pct_total  cul_pct_total  \
# 85       the        7809  17723   1.0   0.041211       0.041211
# 37       and        8543  14005   2.0   0.032565       0.073776
# 15        it        7490  13113   3.0   0.030491       0.104267
# 1         to        7137  12750   4.0   0.029647       0.133914
# 95       for        7990  12224   5.0   0.028424       0.162339
# 98         i        6072  12037   6.0   0.027989       0.190328
# 2          a        6292  10494   7.0   0.024401       0.214729
# 31        is        5538   8508   8.0   0.019783       0.234513
# 51      this        6236   8109   9.0   0.018856       0.253368
# 7         my        6210   7914  10.0   0.018402       0.271770
# 995   tablet        4565   5814  11.0   0.013519       0.285289
# 11     great        4113   4827  12.0   0.011224       0.296513
# 13        of        3132   4365  13.0   0.010150       0.306663
# 235     with        3048   3825  14.0   0.008894       0.315557
# 132       on        2720   3647  15.0   0.008480       0.324038
# 20      that        2384   3293  16.0   0.007657       0.331695
# 397      use        2725   3067  17.0   0.007132       0.338826
# 106      was        2247   2977  18.0   0.006922       0.345749
# 54      have        2309   2945  19.0   0.006848       0.352597
# 100      but        2279   2828  20.0   0.006576       0.359172
# 201       as        1964   2738  21.0   0.006367       0.365539
# 36       you        1649   2691  22.0   0.006257       0.371796
# 286       so        2063   2532  23.0   0.005888       0.377684
# 3       love        2256   2510  24.0   0.005836       0.383520
# 114      not        1817   2372  25.0   0.005516       0.389036
# 154     very        2064   2362  26.0   0.005492       0.394528
# 1168  bought        2217   2352  27.0   0.005469       0.399997
# 1408  kindle        1845   2349  28.0   0.005462       0.405459
# 232     easy        2151   2335  29.0   0.005430       0.410889
# 200     good        2025   2331  30.0   0.005420       0.416309
# 14        in        1828   2323  31.0   0.005402       0.421711
# 12       its        1784   2196  32.0   0.005106       0.426817
# 27       can        1664   2076  33.0   0.004827       0.431644
# 302      one        1618   2052  34.0   0.004771       0.436416
# 104   amazon        1657   2047  35.0   0.004760       0.441175
# 1417     she        1452   2043  36.0   0.004751       0.445926
# 1409    fire        1701   2011  37.0   0.004676       0.450602
# 196    price        1804   1938  38.0   0.004506       0.455108
# 115      has        1681   1912  39.0   0.004446       0.459554
# 1460   loves        1670   1760  40.0   0.004092       0.463647
# 1923    kids        1424   1744  41.0   0.004055       0.467702
# 193      are        1333   1701  42.0   0.003955       0.471657
# 1095     old        1473   1590  43.0   0.003697       0.475354
# 43        an        1315   1545  44.0   0.003593       0.478947
# 78       all        1302   1511  45.0   0.003513       0.482461
# 401     apps        1273   1498  46.0   0.003483       0.485944
# 23      like        1233   1422  47.0   0.003307       0.489250
# 83        be        1165   1416  48.0   0.003293       0.492543
# 225     they        1044   1387  49.0   0.003225       0.495768
# 2062   games        1263   1366  50.0   0.003176       0.498944
#
#       appears_in_pct
# 85          0.557985
# 37          0.610432
# 15          0.535191
# 1           0.509968
# 95          0.570918
# 98          0.433869
# 2           0.449589
# 31          0.395713
# 51          0.445588
# 7           0.443730
# 995         0.326188
# 11          0.293891
# 13          0.223794
# 235         0.217792
# 132         0.194355
# 20          0.170347
# 397         0.194712
# 106         0.160557
# 54          0.164987
# 100         0.162844
# 201         0.140336
# 36          0.117828
# 286         0.147410
# 3           0.161200
# 114         0.129832
# 154         0.147481
# 1168        0.158414
# 1408        0.131833
# 232         0.153698
# 200         0.144695
# 14          0.130618
# 12          0.127474
# 27          0.118900
# 302         0.115613
# 104         0.118399
# 1417        0.103751
# 1409        0.121543
# 196         0.128903
# 115         0.120114
# 1460        0.119328
# 1923        0.101751
# 193         0.095248
# 1095        0.105252
# 43          0.093962
# 78          0.093033
# 401         0.090961
# 23          0.088103
# 83          0.083244
# 225         0.074598
# 2062        0.090247

# %%
import seaborn as sns

# Cumulative Distribution Plot
sns.lineplot(x='rank', y='cul_pct_total', data=wc);

# %%
wc[wc['rank'] <= 100]['cul_pct_total'].max()
# Out:
# 0.6130405666212466

# %%
import squarify
import matplotlib.pyplot as plt

wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ### Processing Raw Text with Spacy
#
# Spacy's datamodel for documents is unique among NLP libraries. Instead of storing the documents components in various data structures, Spacy indexes components and simply stores the lookup information.
#
# This is often why Spacy is considered to be more production grade than library like NLTK.

# %%
import spacy
from spacy.tokenizer import Tokenizer

nlp = spacy.load("en_core_web_lg")

# Tokenizer
tokenizer = Tokenizer(nlp.vocab)

# %%
# Print out list of tokens
sample = "Friends, Romans, countrymen, lend me your ears;"
[token.text for token in tokenizer(sample)]
# Out:
# ['Friends,', 'Romans,', 'countrymen,', 'lend', 'me', 'your', 'ears;']

# %%
# Tokenizer Pipe

tokens = []

""" Make them tokens """
for doc in tokenizer.pipe(df['reviews.text'], batch_size=500):
    doc_tokens = [token.text for token in doc]
    tokens.append(doc_tokens)

df['tokens'] = tokens

# %%
df['tokens'].head()
# Out:
# 8343    [Great, case, to, keep, everything, in, its, p...
# 8344    [After, discarding, and, getting, rid, of, bro...
# 8345    [A, few, dollars, more,, but, I, am, boycottin...
# 8346    [My, initial, impression, of, this, was, very,...
# 8347    [Pros:, Standard, Echo., Cons:, Older, generat...
# Name: tokens, dtype: object

# %%
wc = count(df['tokens'])

# %%
wc.head()
# Out:
#     word  appears_in  count  rank  pct_total  cul_pct_total  appears_in_pct
# 93   the        7230  15157   1.0   0.035131       0.035131        0.516613
# 37   and        8438  13734   2.0   0.031832       0.066963        0.602930
# 0     to        7090  12621   3.0   0.029253       0.096216        0.506610
# 103  for        7811  11753   4.0   0.027241       0.123457        0.558128
# 107    I        5846  11554   5.0   0.026780       0.150237        0.417721

# %%
wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ## Challenge
#
# In the module project, you will apply tokenization to another set of review data and produce visualizations of those tokens.

# %%
list(df)
# Out:
# ['id',
#  'dateAdded',
#  'dateUpdated',
#  'name',
#  'asins',
#  'brand',
#  'categories',
#  'primaryCategories',
#  'imageURLs',
#  'keys',
#  'manufacturer',
#  'manufacturerNumber',
#  'reviews.date',
#  'reviews.dateSeen',
#  'reviews.didPurchase',
#  'reviews.doRecommend',
#  'reviews.id',
#  'reviews.numHelpful',
#  'reviews.rating',
#  'reviews.sourceURLs',
#  'reviews.text',
#  'reviews.title',
#  'reviews.username',
#  'sourceURLs',
#  'tokens']

# %% [markdown]
# # Stop Words (Learn)
# <a id="p2"></a>

# %% [markdown]
# ## Overview
# Section Agenda
# - What are they?
# - How do we get rid of them using Spacy?
# - Visualization
# - Libraries of Stop Words
# - Extending Stop Words
# - Statistical trimming
#
# If the visualizations above, you began to notice a pattern. Most of the words don't really add much to our understanding of product reviews. Words such as "I", "and", "of", etc. have almost no semantic meaning to us. We call these useless words "stop words," because we should 'stop' ourselves from including them in the analysis.
#
# Most NLP libraries have built in lists of stop words that common english words: conjunctions, articles, adverbs, pronouns, and common verbs. The best practice, however, is to extend/customize these standard english stopwords for your problem's domain. If I am studying political science, I may want to exclude the word "politics" from my analysis; it's so common it does not add to my understanding.

# %% [markdown]
# ## Follow Along
#
# ### Default Stop Words
# Let's take a look at the standard stop words that came with our Spacy model:

# %%
# Spacy's Default Stop Words
nlp.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
tokens = []

""" Update those tokens w/o stopwords"""
for doc in tokenizer.pipe(df['reviews.text'], batch_size=500):
    
    doc_tokens = []
    
    for token in doc:
        if (token.is_stop == False) & (token.is_punct == False):
            doc_tokens.append(token.text.lower())

    tokens.append(doc_tokens)

df['tokens'] = tokens

# %%
df.tokens.head()
# Out:
# 8343    [great, case, place!, husband, love, it!!!!, h...
# 8344    [discarding, getting, rid, broken, cd, cases,,...
# 8345                 [dollars, more,, boycotting, amazon]
# 8346    [initial, impression, good., material, nicer, ...
# 8347    [pros:, standard, echo., cons:, older, generat...
# Name: tokens, dtype: object

# %%
wc = count(df['tokens'])

wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ### Extending Stop Words

# %%
print(type(nlp.Defaults.stop_words))
# Out:
# <class 'set'>

# %%
STOP_WORDS = nlp.Defaults.stop_words.union(['batteries','I', 'amazon', 'i', 'Amazon', 'it', "it's", 'it.', 'the', 'this',])

# %%
STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'Amazon',
#  'I',
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'amazon',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'batteries',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  "it's",
#  'it.',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
tokens = []

for doc in tokenizer.pipe(df['reviews.text'], batch_size=500):
    
    doc_tokens = []
    
    for token in doc: 
        if token.text.lower() not in STOP_WORDS:
            doc_tokens.append(token.text.lower())
   
    tokens.append(doc_tokens)
    
df['tokens'] = tokens

# %%
wc = count(df['tokens'])
wc.head()
# Out:
#         word  appears_in  count  rank  pct_total  cul_pct_total  \
# 7      great        3620   4181   1.0   0.020612       0.020612
# 1511  tablet        3463   4176   2.0   0.020588       0.041200
# 1       love        2234   2465   3.0   0.012152       0.053352
# 1227  bought        2194   2327   4.0   0.011472       0.064824
# 161     easy        2107   2275   5.0   0.011216       0.076040
#
#       appears_in_pct
# 7           0.258664
# 1511        0.247446
# 1           0.159628
# 1227        0.156770
# 161         0.150554

# %%
wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %%
df['reviews.rating'].value_counts()
# Out:
# 5    9371
# 4    3703
# 3     551
# 1     187
# 2     183
# Name: reviews.rating, dtype: int64

# %% [markdown]
# ### Statistical Trimming
#
# So far, we have talked about stop word in relation to either broad english words or domain specific stop words. Another common approach to stop word removal is via statistical trimming. The basic idea: preserve the words that give the most about of variation in your data.
#
# Do you remember this graph?

# %%
sns.lineplot(x='rank', y='cul_pct_total', data=wc);

# %% [markdown]
# This graph tells us that only a *handful* of words represented 80% of words in the overall corpus. We can interpret this in two ways:
# 1. The words that appear most frequently may not provide any insight into the mean on the documents since they are so prevalent.
# 2. Words that appear infrequency (at the end of the graph) also probably do not add much value, because the are mentioned so rarely.
#
# Let's take a look at the words at the bottom and the top and make a decision for ourselves:

# %%
wc.tail(20)
# Out:
#                                                     word  appears_in  count  \
# 14454  say..............................................           1      1
# 14453                         kindlelishous!!!!!!!!!!!!!           1      1
# 14455                                         competent,           1      1
# 14456                                        3-year-old,           1      1
# 14457                                          objective           1      1
# 14458                                         dollars.my           1      1
# 14460                                             relies           1      1
# 14459                                               gps.           1      1
# 14461                                            readi,g           1      1
# 14462                                   perfectly..great           1      1
# 14466                                            closes.           1      1
# 14463                                           blanking           1      1
# 14465                                               app"           1      1
# 14464                                        have...then           1      1
# 14467                                             error.           1      1
# 14468                                             moztly           1      1
# 14469                                            titles,           1      1
# 14470                                         it..better           1      1
# 14471                                      shows/movies!           1      1
# 14472                                        bookreader.           1      1
#
#           rank  pct_total  cul_pct_total  appears_in_pct
# 14454  14454.0   0.000005       0.999906        0.000071
# 14453  14455.0   0.000005       0.999911        0.000071
# 14455  14456.0   0.000005       0.999916        0.000071
# 14456  14457.0   0.000005       0.999921        0.000071
# 14457  14458.0   0.000005       0.999926        0.000071
# 14458  14459.0   0.000005       0.999931        0.000071
# 14460  14460.0   0.000005       0.999936        0.000071
# 14459  14461.0   0.000005       0.999941        0.000071
# 14461  14462.0   0.000005       0.999946        0.000071
# 14462  14463.0   0.000005       0.999951        0.000071
# 14466  14464.0   0.000005       0.999956        0.000071
# 14463  14465.0   0.000005       0.999961        0.000071
# 14465  14466.0   0.000005       0.999965        0.000071
# 14464  14467.0   0.000005       0.999970        0.000071
# 14467  14468.0   0.000005       0.999975        0.000071
# 14468  14469.0   0.000005       0.999980        0.000071
# 14469  14470.0   0.000005       0.999985        0.000071
# 14470  14471.0   0.000005       0.999990        0.000071
# 14471  14472.0   0.000005       0.999995        0.000071
# 14472  14473.0   0.000005       1.000000        0.000071

# %%
wc['appears_in_pct'].describe()
# Out:
# count    14473.000000
# mean         0.000945
# std          0.005579
# min          0.000071
# 25%          0.000071
# 50%          0.000143
# 75%          0.000357
# max          0.258664
# Name: appears_in_pct, dtype: float64

# %%
# Frequency of appears in documents
sns.distplot(wc['appears_in_pct']);

# %%
# Tree-Map w/ Words that appear in a least 2.5% of documents. 

wc = wc[wc['appears_in_pct'] >= 0.025]

sns.distplot(wc['appears_in_pct']);

# %%
wc.shape
# Out:
# (67, 7)

# %% [markdown]
# ## Challenge
#
# In the module project, you will apply stop word removal to a new corpus. You will focus on applying dictionary based stop word removal, but as a stretch goal, you should consider applying statistical stopword trimming.

# %% [markdown]
# # Stemming & Lemmatization (Learn)
# <a id="p3"></a>

# %% [markdown]
# ## Overview
#
# You can see from our example above there is still some normalization to do to get a clean analysis. You notice that there many words (*i.e.* 'batteries', 'battery') which share the same root word. We can use either the process of stemming or lemmatization to trim our words down to the 'root' word.
#
# __Section Agenda__:
#
# - Which is which
# - why use one v. other
# - show side by side visualizations
# - how to do it in spacy & nltk
# - introduce PoS in here as well

# %% [markdown]
# ## Follow Along

# %% [markdown]
# ### Stemming
#
# > *a process for removing the commoner morphological and inflexional endings from words in English. Its main use is as part of a term normalisation process that is usually done when setting up Information Retrieval systems.* - [Martin Porter](https://tartarus.org/martin/PorterStemmer/)
#
# Some examples include:
# - 'ing'
# - 'ed'
# - 's'
#
# These rules are by no means comprehensive, but they are somewhere to start. Most stemming is done by well documented algorithms such as Porter, Snowball, and Dawson. Porter and its newer version Snowball are the most popular stemming algorithms today. For more information on various stemming algorithms check out [*"A Comparative Study of Stemming Algorithms"*](https://pdfs.semanticscholar.org/1c0c/0fa35d4ff8a2f925eb955e48d655494bd167.pdf)
#
#
# Spacy does not do stemming out of the box, but instead uses a different technique called *lemmatization* which we will discuss in the next section. Let's turn to an antique python package `nltk` for stemming.

# %%
d
# Out:
# ['discarding',
#  'getting',
#  'rid',
#  'broken',
#  'cd',
#  'cases,',
#  'broken',
#  'cds,',
#  'selecting',
#  'ones',
#  'like,',
#  'binder',
#  'turned',
#  'excellent',
#  'option',
#  'store',
#  'favourite',
#  'cds',
#  'dvds',
#  'small',
#  'space',
#  'living',
#  'room,',
#  'giving',
#  'choice',
#  'donate',
#  'rid',
#  'cds',
#  'towers',
#  'took',
#  'lot',
#  'room,',
#  'despite',
#  'looking',
#  'nice.',
#  'turn',
#  'pages,',
#  'spot',
#  'cd',
#  'want',
#  'play',
#  'hassle',
#  'taking',
#  'case',
#  'falling',
#  'apart.',
#  'storing',
#  'cds,',
#  'cases',
#  'printed',
#  'covers',
#  'went',
#  'straight',
#  'recycling',
#  'centre.',
#  'small',
#  'version',
#  'cds',
#  'husband',
#  'like',
#  'listen',
#  'drive',
#  'away',
#  'work.']

# %%
from nltk.stem import PorterStemmer

ps = PorterStemmer()

words = ["wolf", "wolves"]

for word in words:
    print(ps.stem(word))
# Out:
# wolf
# wolv

# %% [markdown]
# ### Two Minute Challenge
#
# Apply the Porter stemming algorithm to the tokens in the `df` dataframe. Visualize the results in the tree graph we have been using for this session.

# %%
word_list = []
for i in range(0,len(df)):
    words = df['tokens'].iloc[i]
    new_words = []
    for word in words:
        new_words.append(ps.stem(word))
        
    
    word_list.append(new_words)
    
word_list
# Out:
# [['great',
#   'case',
#   'place!',
#   'husband',
#   'love',
#   'it!!!!',
#   'hold',
#   'lot',
#   'cds!'],
#  ['discard',
#   'get',
#   'rid',
#   'broken',
#   'cd',
#   'cases,',
#   'broken',
#   'cds,',
#   'select',
#   'one',
#   'like,',
#   'binder',
#   'turn',
#   'excel',
#   'option',
#   'store',
#   'favourit',
#   'cd',
#   'dvd',
#   'small',
#   'space',
#   'live',
#   'room,',
#   'give',
#   'choic',
#   'donat',
#   'rid',
#   'cd',
#   'tower',
#   'took',
#   'lot',
#   'room,',
#   'despit',
#   'look',
#   'nice.',
#   'turn',
#   'pages,',
#   'spot',
#   'cd',
#   'want',
#   'play',
#   'hassl',
#   'take',
#   'case',
#   'fall',
#   'apart.',
#   'store',
#   'cds,',
#   'case',
#   'print',
#   'cover',
#   'went',
#   'straight',
#   'recycl',
#   'centre.',
#   'small',
#   'version',
#   'cd',
#   'husband',
#   'like',
#   'listen',
#   'drive',
#   'away',
#   'work.'],
#  ['dollar', 'more,', 'boycot'],
#  ['initi',
#   'impress',
#   'good.',
#   'materi',
#   'nicer',
#   'shini',
#   'stuff',
#   'hama',
#   'cd',
#   'binder',
#   'net',
#   'trim',
#   'give',
#   'nice',
#   'appear',
#   'compar',
#   'plain',
#   'look',
#   'budget',
#   'cd',
#   'binders.ther',
#   '50',
#   'page',
#   '8',
#   'disc',
#   'pocket',
#   '(4',
#   'side)',
#   'give',
#   'total',
#   '400',
#   'capacity.',
#   'page',
#   'hung',
#   'spine',
#   'group',
#   '25.',
#   'mean',
#   '25',
#   'page',
#   'singl',
#   'attach',
#   'point',
#   'plastic',
#   'spine.thi',
#   'problem',
#   'binder',
#   'lies.',
#   'group',
#   '25',
#   'page',
#   'share',
#   'anchor',
#   'point',
#   'spine,',
#   'page',
#   'sit',
#   'flat',
#   'discs.',
#   'bend',
#   'arch,',
#   'apart',
#   'look',
#   'tatti',
#   'put',
#   'lot',
#   'tension',
#   'plastic',
#   'film.',
#   'long-term',
#   'usag',
#   'suspect',
#   'plastic',
#   'film',
#   'tear',
#   'tension.',
#   'make',
#   'awkward',
#   'brows',
#   'binder',
#   'page',
#   "don't",
#   'sit',
#   'flat.',
#   'crack',
#   'bend',
#   'discs.i',
#   'look',
#   'hama',
#   '120',
#   'binder',
#   '*should*',
#   '-',
#   '30',
#   'page',
#   'smart',
#   'hang',
#   'spine',
#   '3',
#   'bundl',
#   '10.',
#   'spread',
#   'page',
#   'allow',
#   'easi',
#   'brows',
#   'binder',
#   'put',
#   'pocket',
#   'tension.aft',
#   '2',
#   'week',
#   'storag',
#   'open',
#   'binder',
#   'corner',
#   'page',
#   'dog-ear',
#   'themselves.',
#   'poor',
#   'design',
#   'poor',
#   'fit',
#   'binder',
#   'page',
#   'fill',
#   'discs.',
#   'again,',
#   'problem',
#   'seen',
#   'disc',
#   'binders,',
#   'two-year-old',
#   'hama',
#   'binder',
#   'look',
#   'good',
#   'new.over',
#   'binder',
#   'lot',
#   'storag',
#   'good',
#   'price.',
#   "that'",
#   'want',
#   'probabl',
#   'happi',
#   'product.',
#   'sloppi',
#   'design',
#   'prevent',
#   'mediocr',
#   'binder.',
#   'feel',
#   'design',
#   'bother',
#   'fill',
#   'disc',
#   'cope.'],
#  ['pros:',
#   'standard',
#   'echo.',
#   'cons:',
#   'older',
#   'gener',
#   'echo.',
#   'thoughts:',
#   'arriv',
#   'time',
#   'new',
#   'box.'],
#  ['pros:',
#   'got',
#   '50,',
#   'impress',
#   'sound',
#   '2nd',
#   'gen.',
#   'functionality.',
#   'cons:',
#   'trendi',
#   'look',
#   'newer,',
#   'set',
#   'kitchen',
#   'island'],
#  ['pros:',
#   'love',
#   'alexa',
#   'seri',
#   'went',
#   'sale',
#   'camera.',
#   'watch',
#   'secur',
#   'camera',
#   'couch',
#   'drop',
#   'what',
#   'go',
#   'places.',
#   'audio',
#   'nice',
#   'loud',
#   'pictur',
#   'clear',
#   'cons:',
#   'wish',
#   'stop',
#   'screen',
#   'turn',
#   'think',
#   'unplug',
#   'save',
#   'power',
#   'guess'],
#  ['asid',
#   'fact',
#   'screen',
#   'small,',
#   'great',
#   'littl',
#   'device.',
#   'prefer',
#   'larger',
#   'screen,',
#   'echo',
#   'better',
#   'choice.'],
#  ["wasn't",
#   'sure',
#   'want',
#   'item,',
#   'caught',
#   'excit',
#   'surround',
#   'alexa',
#   'enabl',
#   'devices.',
#   'well....aft',
#   'get',
#   'home',
#   'addict',
#   'order',
#   'echo',
#   'entertain',
#   'stand',
#   'today',
#   'sub',
#   'coming.',
#   "can't",
#   'product',
#   'quick',
#   'service/pick',
#   'target',
#   'store.',
#   'great',
#   'servic',
#   'product!'],
#  ['pros:',
#   'work',
#   'good',
#   'like',
#   'alexia',
#   'cons:',
#   'set',
#   ',',
#   'hasl',
#   'verizon',
#   'time',
#   'thoughts:',
#   'recommend'],
#  ['pros:',
#   'rel',
#   'easi',
#   'setup',
#   'work',
#   'reliably.',
#   'cons:',
#   'mirror',
#   'cast',
#   'function',
#   "didn't",
#   'work',
#   'display',
#   'video',
#   'steam',
#   'window',
#   '10',
#   'laptop.',
#   'thoughts:',
#   'product',
#   'recommend',
#   'cowork',
#   'skeptic',
#   'first,',
#   'product',
#   'turn',
#   'reli',
#   'entertain',
#   'access.'],
#  ['pros:',
#   'recommend',
#   'go',
#   'purchas',
#   ',',
#   'newegg',
#   'best',
#   'place',
#   'look',
#   '!',
#   'cons:',
#   'compaint'],
#  ['pros:',
#   'allow',
#   'cut',
#   'cable.',
#   'app',
#   'download',
#   'app',
#   'allow',
#   'free',
#   'use',
#   'servic',
#   'stream',
#   'long',
#   'cabl',
#   'provid',
#   '(at',
#   'internet),',
#   'log',
#   'stream.',
#   'use',
#   'app',
#   'like',
#   'kodi',
#   'tubitv',
#   'watch',
#   'shows.',
#   'favorit',
#   'tubitv.',
#   'yes,',
#   'commerci',
#   'services.buy',
#   'this,',
#   'check',
#   'out,',
#   'enjoy',
#   'freedom',
#   'cabl',
#   'tv!',
#   'cons:',
#   "don't",
#   'complaints.'],
#  ['pros:',
#   "i'm",
#   'subscrib',
#   'directtv',
#   'now!',
#   'pay',
#   'yearli',
#   'discount',
#   '450+',
#   'channel',
#   'stream',
#   'tv',
#   '59',
#   'month,',
#   'pay',
#   'prime/netflix.',
#   'combined,',
#   'cabl',
#   'bill',
#   '172.00',
#   'choic',
#   'options,',
#   'got',
#   'compon',
#   'run',
#   'ethernet,',
#   'lag.i',
#   'un-met',
#   'fiber',
#   'optic,',
#   'stream',
#   'lot,',
#   'given',
#   'famili',
#   'good',
#   'leav',
#   'running.',
#   'cons:',
#   "tv'",
#   'hdmi',
#   'port',
#   "don't",
#   'extend',
#   'difficult',
#   'install,',
#   '4k',
#   'tv',
#   'port',
#   'took',
#   'like',
#   '4',
#   'minutes.',
#   'wireless',
#   'pointless',
#   'ethernet',
#   'addon'],
#  ['pros:',
#   'satisfi',
#   'buy',
#   'onlin',
#   'wonder',
#   'servic',
#   'good',
#   'qualiti',
#   'seal',
#   'pack',
#   'good',
#   'pack',
#   'cons:',
#   'great',
#   'thoughts:',
#   'satisfi',
#   'thank'],
#  ['incom',
#   'tax',
#   'prepar',
#   'practic',
#   "i'm",
#   'laptop',
#   '10',
#   'hour',
#   'day',
#   'enter',
#   'data.',
#   'laptop',
#   'keyboard',
#   'mous',
#   'pad',
#   'flat',
#   'level',
#   'angl',
#   'laptop',
#   'offer',
#   'stressful.',
#   'elev',
#   'keyboard',
#   'serv',
#   'purpos',
#   "'tilting'",
#   'keyboard',
#   'natur',
#   'posit',
#   'typing.',
#   'amazonbas',
#   'ventil',
#   'adjust',
#   'laptop',
#   'stand',
#   'perfect',
#   'produc',
#   'effect',
#   'typewrit',
#   'slant',
#   'grew',
#   'ibm',
#   'selectr',
#   'royals.',
#   'fulli',
#   'adjust',
#   'angl',
#   'comfort',
#   'with.',
#   'made,',
#   'light',
#   'weight',
#   'look',
#   "'piec",
#   "laptop'",
#   'sight.',
#   'small',
#   'warning:',
#   'tab',
#   'end',
#   'laptop',
#   'slide',
#   'bit',
#   'short',
#   'laptops.',
#   'tab',
#   'rise',
#   '.75',
#   'inch',
#   '(3/4).',
#   'current,',
#   'past',
#   'laptops,',
#   'sit',
#   '1.0',
#   'inch',
#   '(1)',
#   'slant',
#   '.75',
#   'inch',
#   '(3/4)',
#   'inward.',
#   'slant',
#   'keep',
#   'tab',
#   'stand',
#   'hold',
#   'laptop',
#   'place',
#   '-',
#   'caus',
#   'laptop',
#   'slip',
#   'off.',
#   'simpl',
#   'solut',
#   'this:',
#   'binder',
#   'clips.',
#   'use',
#   'medium',
#   'size',
#   'binder',
#   'clip,',
#   'stand',
#   'tabs.',
#   'find',
#   "'binder",
#   "clips'",
#   'web',
#   'site.',
#   'box',
#   '4',
#   'need',
#   '2',
#   'medium',
#   'binder',
#   'clip',
#   '.',
#   '.',
#   '.',
#   'check',
#   'school',
#   'teacher',
#   'offic',
#   'worker',
#   'free.',
#   'that,',
#   'right',
#   'tool',
#   'right',
#   'price.',
#   'buy',
#   'yourself.',
#   "you'll",
#   'glad',
#   'did.'],
#  ['simpl',
#   'design,',
#   'multipl',
#   'angles,',
#   'mesh',
#   'keep',
#   'laptop',
#   'cool,',
#   'cord',
#   'keeper',
#   'keep',
#   'organized,',
#   'surfac',
#   'area',
#   'great',
#   '15.6',
#   'laptop.',
#   'think',
#   'work',
#   '17',
#   'laptop,',
#   'larger',
#   'model',
#   'those.',
#   'check',
#   'first.',
#   'gripe',
#   'unit',
#   "'tabs'",
#   'laptop',
#   'slide',
#   'lap',
#   'adjust',
#   'angle.',
#   'tab',
#   'benefit',
#   '1/2',
#   'taller',
#   'are.',
#   'allow',
#   "'thicker'",
#   'laptop',
#   'base',
#   "'spillage'",
#   'like',
#   'toshiba',
#   'occasion',
#   'do.',
#   'con',
#   'item.',
#   'suggest',
#   'buy'],
#  ["can't",
#   'awesom',
#   'stand.',
#   'allow',
#   'util',
#   'laptop',
#   'monitor',
#   'second',
#   'flawlessly.',
#   'cord',
#   'great',
#   'well.',
#   'purchas',
#   'monitor',
#   'choic',
#   'adjust',
#   'angle,',
#   'stand',
#   'place',
#   'screen',
#   'perfectli',
#   'well.ther',
#   'vibrat',
#   'metal',
#   'contact',
#   'padded.',
#   'fan',
#   'laptop',
#   'come',
#   'day',
#   'long',
#   'upload',
#   'cloud',
#   'stand',
#   'have',
#   'suspend',
#   'air',
#   'mesh.very,',
#   'glad',
#   'purchase.',
#   'easili',
#   'worth',
#   'paid,',
#   'option',
#   'adjust',
#   'angl',
#   'ample,',
#   'let',
#   'expens',
#   'babi',
#   'run',
#   'cool.',
#   'buy',
#   'confidence!'],
#  ["can't",
#   'awesom',
#   'stand.',
#   'allow',
#   'util',
#   'laptop',
#   'monitor',
#   'second',
#   'flawlessly.',
#   'cord',
#   'great',
#   'well.',
#   'purchas',
#   'monitor',
#   'choic',
#   'adjust',
#   'angle,',
#   'stand',
#   'place',
#   'screen',
#   'perfectli',
#   'well.ther',
#   'vibrat',
#   'metal',
#   'contact',
#   'padded.',
#   'fan',
#   'laptop',
#   'come',
#   'day',
#   'long',
#   'upload',
#   'cloud',
#   'stand',
#   'have',
#   'suspend',
#   'air',
#   'mesh.very,',
#   'glad',
#   'purchase.',
#   'easili',
#   'worth',
#   'paid,',
#   'option',
#   'adjust',
#   'angl',
#   'ample,',
#   'let',
#   'expens',
#   'babi',
#   'run',
#   'cool.',
#   'buy',
#   'confidence!'],
#  ["can't",
#   'awesom',
#   'stand.',
#   'allow',
#   'util',
#   'laptop',
#   'monitor',
#   'second',
#   'flawlessly.',
#   'cord',
#   'great',
#   'well.',
#   'purchas',
#   'monitor',
#   'choic',
#   'adjust',
#   'angle,',
#   'stand',
#   'place',
#   'screen',
#   'perfectli',
#   'well.ther',
#   'vibrat',
#   'metal',
#   'contact',
#   'padded.',
#   'fan',
#   'laptop',
#   'come',
#   'day',
#   'long',
#   'upload',
#   'cloud',
#   'stand',
#   'have',
#   'suspend',
#   'air',
#   'mesh.very,',
#   'glad',
#   'purchase.',
#   'easili',
#   'worth',
#   'paid,',
#   'option',
#   'adjust',
#   'angl',
#   'ample,',
#   'let',
#   'expens',
#   'babi',
#   'run',
#   'cool.',
#   'buy',
#   'confidence!'],
#  ['guard',
#   'stop',
#   'way',
#   'high.',
#   'dig',
#   'wrist',
#   'pain',
#   '5',
#   'minutes.everyth',
#   'stand',
#   'excel',
#   '13',
#   'laptop.',
#   "it'll",
#   'work',
#   'use',
#   'extend',
#   'keyboard.imposs',
#   'type',
#   'directli',
#   'laptop',
#   'b/c',
#   'poor',
#   'design.',
#   'guard',
#   'need',
#   'brought',
#   '1/2',
#   'size',
#   'perfect.'],
#  ['use',
#   'laptop',
#   'lap.',
#   'figure.',
#   '17',
#   'inch',
#   'laptop',
#   'tire',
#   'portabl',
#   'laptop',
#   'holders,',
#   'plastic,',
#   'broken',
#   'coupl',
#   'months.',
#   'metal',
#   'lightweight.',
#   'ad',
#   'valu',
#   'have',
#   'flat,',
#   'perfor',
#   'base',
#   'make',
#   'comfort',
#   'lap',
#   'give',
#   'place',
#   'place',
#   'peripher',
#   'extern',
#   'hard',
#   'drives.',
#   'happi',
#   'product',
#   'recommend'],
#  ['laptop',
#   'cooler',
#   'purchas',
#   'usb',
#   'plug',
#   'run',
#   'fan.',
#   'got',
#   'tire',
#   'fan',
#   'make',
#   'noise,',
#   'usb',
#   'cooler',
#   'plug',
#   'work',
#   'eventu',
#   'etc.so',
#   'gave',
#   'shot',
#   'say',
#   'plus.',
#   'keep',
#   '15.6',
#   'mac',
#   'book',
#   'pro',
#   'cool',
#   'leg',
#   'heat',
#   'sit',
#   'couch.',
#   'feel',
#   'nearli',
#   'hot',
#   'to.',
#   '4',
#   'stars.',
#   'tab',
#   'laptop',
#   'slide',
#   'adjust',
#   'type',
#   'arm',
#   'want',
#   'rest',
#   'tabs.',
#   'uncomfortable.',
#   'pictur',
#   'slight',
#   'modif',
#   'allevi',
#   'problem.',
#   'rest',
#   'laptop',
#   'pad',
#   'type',
#   'arm',
#   'rest',
#   'key',
#   'board',
#   'portion',
#   'tab',
#   'there.',
#   'comfortable.',
#   'strip',
#   'thick',
#   'felt',
#   'sticki',
#   'bottoms.',
#   'certainli',
#   'technic',
#   'fix',
#   'job.',
#   'includ',
#   'metal',
#   'piec',
#   'retrofit',
#   'portion',
#   'allow',
#   'rais',
#   'comput',
#   'level',
#   'tab',
#   'interfere.',
#   'simpl',
#   'mayb',
#   'model.',
#   'check',
#   'photos.'],
#  ['laptop',
#   'cooler',
#   'purchas',
#   'usb',
#   'plug',
#   'run',
#   'fan.',
#   'got',
#   'tire',
#   'fan',
#   'make',
#   'noise,',
#   'usb',
#   'cooler',
#   'plug',
#   'work',
#   'eventu',
#   'etc.so',
#   'gave',
#   'shot',
#   'say',
#   'plus.',
#   'keep',
#   '15.6',
#   'mac',
#   'book',
#   'pro',
#   'cool',
#   'leg',
#   'heat',
#   'sit',
#   'couch.',
#   'feel',
#   'nearli',
#   'hot',
#   'to.',
#   '4',
#   'stars.',
#   'tab',
#   'laptop',
#   'slide',
#   'adjust',
#   'type',
#   'arm',
#   'want',
#   'rest',
#   'tabs.',
#   'uncomfortable.',
#   'pictur',
#   'slight',
#   'modif',
#   'allevi',
#   'problem.',
#   'rest',
#   'laptop',
#   'pad',
#   'type',
#   'arm',
#   'rest',
#   'key',
#   'board',
#   'portion',
#   'tab',
#   'there.',
#   'comfortable.',
#   'strip',
#   'thick',
#   'felt',
#   'sticki',
#   'bottoms.',
#   'certainli',
#   'technic',
#   'fix',
#   'job.',
#   'includ',
#   'metal',
#   'piec',
#   'retrofit',
#   'portion',
#   'allow',
#   'rais',
#   'comput',
#   'level',
#   'tab',
#   'interfere.',
#   'simpl',
#   'mayb',
#   'model.',
#   'check',
#   'photos.'],
#  ['laptop',
#   'cooler',
#   'purchas',
#   'usb',
#   'plug',
#   'run',
#   'fan.',
#   'got',
#   'tire',
#   'fan',
#   'make',
#   'noise,',
#   'usb',
#   'cooler',
#   'plug',
#   'work',
#   'eventu',
#   'etc.so',
#   'gave',
#   'shot',
#   'say',
#   'plus.',
#   'keep',
#   '15.6',
#   'mac',
#   'book',
#   'pro',
#   'cool',
#   'leg',
#   'heat',
#   'sit',
#   'couch.',
#   'feel',
#   'nearli',
#   'hot',
#   'to.',
#   '4',
#   'stars.',
#   'tab',
#   'laptop',
#   'slide',
#   'adjust',
#   'type',
#   'arm',
#   'want',
#   'rest',
#   'tabs.',
#   'uncomfortable.',
#   'pictur',
#   'slight',
#   'modif',
#   'allevi',
#   'problem.',
#   'rest',
#   'laptop',
#   'pad',
#   'type',
#   'arm',
#   'rest',
#   'key',
#   'board',
#   'portion',
#   'tab',
#   'there.',
#   'comfortable.',
#   'strip',
#   'thick',
#   'felt',
#   'sticki',
#   'bottoms.',
#   'certainli',
#   'technic',
#   'fix',
#   'job.',
#   'includ',
#   'metal',
#   'piec',
#   'retrofit',
#   'portion',
#   'allow',
#   'rais',
#   'comput',
#   'level',
#   'tab',
#   'interfere.',
#   'simpl',
#   'mayb',
#   'model.',
#   'check',
#   'photos.'],
#  ['simple,',
#   'appear',
#   'durable.',
#   'size',
#   'mean',
#   'sit',
#   'favorit',
#   'chair',
#   'laptop.',
#   'unit',
#   'larger',
#   'wanted,',
#   'overli',
#   'complic',
#   'subject',
#   'breakage.'],
#  ["you'r",
#   'look',
#   'laptop',
#   'cool,',
#   'trick.',
#   'bad',
#   'thing',
#   'are,',
#   "isn't",
#   'comfort',
#   'sit',
#   'lap',
#   'metal',
#   "isn't",
#   'awesome.',
#   'rivet',
#   'rest',
#   'hand',
#   'weld',
#   'thing',
#   "they'r",
#   'uncomfort',
#   'dig',
#   'hand',
#   'tri',
#   'type',
#   'rest',
#   'hands.',
#   "wouldn't",
#   'recommend..'],
#  ['basic,',
#   'function',
#   'backpack',
#   'job',
#   'design',
#   'for.',
#   'unlik',
#   'other,',
#   'expens',
#   'models,',
#   'feel',
#   'look',
#   'friends.',
#   'however,',
#   'hold',
#   '16',
#   'laptop',
#   'pocket',
#   'contain',
#   'usual',
#   'travel',
#   'gear.',
#   'materi',
#   'fairli',
#   'durabl',
#   'make',
#   'crinkli',
#   'sound',
#   'touch',
#   'moved.',
#   'good',
#   'choic',
#   'teenag',
#   'hard',
#   'belongings.'],
#  ['purchas',
#   'backpack',
#   'wife',
#   "son'",
#   'laptops.',
#   'case',
#   'construct',
#   'compartments.',
#   'great',
#   'backpack',
#   'price.'],
#  ['love',
#   'backpack....lot',
#   'pocket',
#   'needs...when',
#   'travel',
#   'fit',
#   'travel...mak',
#   'lot',
#   'easier'],
#  ['small', '17', 'envi', 'tight', 'fit.', 'great', 'product'],
#  ['bag',
#   'fit',
#   '17.3',
#   'laptop',
#   'snuggly,',
#   'fit',
#   'nonetheless.',
#   'consider',
#   'space',
#   'avail',
#   'sections,',
#   'accessori',
#   'pocket',
#   'smaller',
#   'items.',
#   '2',
#   'mesh',
#   'pocket',
#   'big',
#   'standard',
#   'plastic',
#   'water',
#   'bottle,',
#   'big',
#   'nalgen',
#   'water',
#   'bottle.tak',
#   'coupl',
#   'destin',
#   'issu',
#   'find',
#   'it,',
#   'edit',
#   'comment',
#   'accordingly.',
#   'stand',
#   'now,',
#   'good',
#   'solid',
#   'bag',
#   'price',
#   'fit',
#   'larger',
#   'laptops.'],
#  ['love'],
#  ['great', 'price', 'durabl', 'walmart.'],
#  ['backpack',
#   'great',
#   'quality.',
#   'reason',
#   'gave',
#   '4/5',
#   'star',
#   "wouldn't",
#   'trust',
#   'laptop',
#   'slot',
#   'protect',
#   'laptop.',
#   'pad',
#   'enough.',
#   'choic',
#   "i'd",
#   'laptop',
#   'slot',
#   'replac',
#   'waterproof',
#   'cooler',
#   'space',
#   'purchas',
#   'hiking.',
#   'gripe,',
#   'bag',
#   'great',
#   'quality,',
#   'comfort',
#   'plenti',
#   'space.',
#   'worth',
#   'price.'],
#  ['zipper',
#   'imo.',
#   'good',
#   'quality,',
#   'zipper',
#   'frequent',
#   'caught',
#   'make',
#   'slightli',
#   'annoy',
#   'open.'],
#  ['amazing.....',
#   'sturdi',
#   'pocketed....',
#   'worth',
#   'investment...veri',
#   'happi',
#   'purchase.',
#   'hold',
#   'nicely.'],
#  ['pros:wel',
#   'made/good',
#   'constructioncompar',
#   'favor',
#   'famou',
#   'brand-nam',
#   'packsno',
#   'obviou',
#   'brandinggreat',
#   'attent',
#   'detaillarg',
#   'main',
#   'compartmentlot',
#   'subcompartmentsorgan',
#   'pens/sundri',
#   'compartmentcons:gener',
#   'lookstop',
#   'handl',
#   'minim',
#   'padded/perfunctorystiff',
#   'nylon',
#   'interior',
#   'part',
#   'make',
#   'audibl',
#   "'crinkly'",
#   'sound',
#   'movedth',
#   'amazonbas',
#   'laptop',
#   'backpack',
#   'well-made,',
#   'fulli',
#   'featur',
#   'backpack',
#   'accommod',
#   'laptop',
#   '17',
#   'inch',
#   'wide.',
#   'simpli',
#   'design',
#   'good',
#   'look',
#   'backpack',
#   'meet',
#   "students'",
#   'needs.th',
#   'bag',
#   'basic',
#   'simple,',
#   'stylish',
#   'design,',
#   'grey',
#   'highlight',
#   'orang',
#   'pipe',
#   'front.',
#   'characterist',
#   'bag',
#   'distinct',
#   'obviou',
#   'brand',
#   'front.',
#   'look',
#   'closely,',
#   'find',
#   'basic',
#   'logo',
#   'emboss',
#   'black',
#   'zippers.',
#   "you'd",
#   'look',
#   'closely.',
#   'shoulder',
#   'strap',
#   'back',
#   'mesh-lik',
#   'materi',
#   'reduc',
#   'slippag',
#   'suffici',
#   'wide',
#   'pad',
#   'comfortable.th',
#   'main',
#   'compart',
#   'gener',
#   'size,',
#   'open',
#   'close',
#   'zippers,',
#   'basic',
#   'broken',
#   'areas.',
#   'area',
#   'gener',
#   'pad',
#   'side',
#   'meant',
#   'hous',
#   'laptop.',
#   'pad',
#   'good',
#   'gener',
#   'seen',
#   'standard',
#   'backpack',
#   'compani',
#   'like',
#   'jansport',
#   'l.l.',
#   'bean.',
#   'singl',
#   'larg',
#   'sleev',
#   'pad',
#   'larg',
#   'hold',
#   'standard,',
#   'letter-s',
#   'manilla',
#   'folder',
#   'fill',
#   'papers.',
#   'compart',
#   'basic',
#   'wide',
#   'open',
#   'room',
#   'tradit',
#   'textbook',
#   '(assum',
#   'peopl',
#   'use',
#   'these)',
#   'paraphernalia.ther',
#   'compart',
#   'front.',
#   'mid-siz',
#   'compart',
#   'main',
#   'compart',
#   'smaller',
#   'compart',
#   'obligatori',
#   'organizer/pocket',
#   'hold',
#   'pens,',
#   'cellphon',
#   'etc.',
#   'intern',
#   'clip',
#   'compart',
#   'keys.additionally,',
#   'small',
#   'mesh',
#   'pocket',
#   'side',
#   'pack',
#   'quick-access,',
#   'zipper',
#   'pocket',
#   'pack.',
#   "there'",
#   'small',
#   'mesh',
#   'pocket',
#   'left',
#   'shoulder',
#   'strap.although',
#   'doubt',
#   'ballist',
#   'nylon,',
#   'appear',
#   'made.',
#   'edg',
#   'line',
#   'dog-ear',
#   'fabric.',
#   'handl',
#   'minim',
#   'pad',
#   'bit',
#   'flimsi',
#   'pack',
#   'size.',
#   'clearly,',
#   'lift',
#   'pack',
#   'handl',
#   'floor',
#   'desk,',
#   'handl',
#   "isn't",
#   'comfort',
#   'sturdi',
#   'carri',
#   'pack',
#   'like',
#   'suitcase.',
#   'nylon',
#   'make',
#   'divid',
#   'stiff',
#   'make',
#   'audibl',
#   'crinkli',
#   'sound',
#   'manipulated.',
#   'like',
#   'away',
#   'time,',
#   'late',
#   'class',
#   'walk',
#   'quiet',
#   'lectur',
#   'hall',
#   'distraction.th',
#   'zipper',
#   'easily.',
#   'larg',
#   'grip',
#   'nylon',
#   'tag',
#   'sewn',
#   'end',
#   'easier',
#   'pull.',
#   'zipper',
#   'strong',
#   'pack',
#   'size',
#   'caliber.all-in-al',
#   'pack',
#   'excel',
#   'price',
#   'point.',
#   'win',
#   'major',
#   'style',
#   'point',
#   'students,',
#   'great',
#   'basic',
#   'backpack.'],
#  ['order',
#   'backpack',
#   'anticip',
#   '10-day',
#   'vacat',
#   'univers',
#   'studio',
#   'royal',
#   'caribbean',
#   'cruise.',
#   'need',
#   'carri',
#   'laptop',
#   'easili',
#   'remov',
#   'security,',
#   'lot',
#   'pocket',
#   'travel',
#   'paper',
#   'thing',
#   'need',
#   '6yo',
#   'busy.thi',
#   'amazonbas',
#   'laptop',
#   'well-mad',
#   'sturdi',
#   'varieti',
#   'pocket',
#   'size',
#   'place',
#   'stuff.',
#   'materi',
#   'insid',
#   'bag',
#   'make',
#   'loud',
#   'crinkly,',
#   'easi',
#   'clean.',
#   'pocket',
#   'extran',
#   'get',
#   'way,',
#   'pocket',
#   'closed,',
#   'abund',
#   'zipper',
#   'pulls.',
#   'bag',
#   'travel',
#   'like',
#   'sleeker',
#   'style',
#   'it.th',
#   'backpack',
#   'bit',
#   'everyday',
#   'use',
#   '(just',
#   'bulk',
#   'number',
#   'pockets,',
#   'etc),',
#   "i'm",
#   'happi',
#   'futur',
#   'travels.'],
#  ['expect',
#   'backpack',
#   'littl',
#   'flimsi',
#   'consid',
#   'price',
#   'great.',
#   'pad',
#   'laptop',
#   'pocket',
#   'nice',
#   'thick.',
#   'secondari',
#   'pocket',
#   'laptop',
#   'pouch',
#   'fit',
#   '8',
#   'tablet.',
#   'overal',
#   'like',
#   'pocket',
#   'littl',
#   'compartments.',
#   'bad',
#   'thing',
#   'cheap',
#   'materi',
#   'insid',
#   'like',
#   'pocket',
#   'stuff',
#   'flimsi',
#   "it'll",
#   'easili',
#   'punctur',
#   'pen',
#   'pencil',
#   'stuff.',
#   "that'",
#   'big',
#   'deal',
#   'outsid',
#   'sturdi',
#   'stuff',
#   'safe.'],
#  ['nice',
#   'bag',
#   'lot',
#   'compart',
#   'plenti',
#   'room',
#   'laptop,',
#   'tablet,',
#   'notebook,',
#   'accessories.',
#   'especi',
#   'like',
#   'cinch',
#   'strap',
#   'adjust',
#   'width',
#   'items.',
#   'zipper',
#   'littl',
#   'tight',
#   'first,',
#   'quickli',
#   'loosen',
#   'up.'],
#  ['amazonbas',
#   'deliv',
#   'qualiti',
#   'backpack',
#   'price.',
#   'like',
#   'differ',
#   'pocket',
#   'gear',
#   'organized.',
#   'materi',
#   'backpack',
#   'light',
#   'weight',
#   'strong.',
#   'work',
#   'great',
#   'travel',
#   'held',
#   'need',
#   'travel',
#   'with.',
#   'recommend',
#   'backpack',
#   'travel',
#   'larg',
#   'laptop,',
#   '17',
#   'inch',
#   'fit',
#   'perfectly.'],
#  ['bag',
#   'fit',
#   '17-inch',
#   'laptop,',
#   'littl',
#   'bigger',
#   'many.',
#   'need',
#   'rel',
#   'thin',
#   '17-inch',
#   'laptop',
#   'work.',
#   'also,',
#   'review',
#   'described,',
#   'cheap-feel',
#   'inner',
#   'lining.',
#   'like',
#   'zipper',
#   'main',
#   'pocket',
#   'extend',
#   'base',
#   'farther,',
#   'open',
#   'wide',
#   'like.',
#   'job',
#   'serv',
#   'replac',
#   'previou',
#   'backpack,',
#   'fall',
#   'apart,',
#   'think',
#   'recommend',
#   'anyone.'],
#  ['depart', 'idem', 'perfectli', 'design', 'fit', 'needs.'],
#  ['lot',
#   'pockets,',
#   'zipper',
#   'cover',
#   'actual',
#   'open',
#   'close',
#   'bit',
#   'difficult.'],
#  ['deliv',
#   'promised,',
#   'packag',
#   '...',
#   'problem',
#   '...',
#   'appear',
#   'waterproof',
#   '...',
#   'good',
#   'thing',
#   'heavi',
#   'south',
#   'florida',
#   'rains.'],
#  ["there'",
#   'lot',
#   'space',
#   'basic',
#   'laptop',
#   'number',
#   'great',
#   'compartments,',
#   'materi',
#   'feel',
#   'kind',
#   'stiff',
#   'inexpensive.',
#   'impress',
#   'backpack,',
#   'pack',
#   'felt',
#   'big',
#   'bulky.',
#   'normal',
#   'backpack',
#   'smaller',
#   'timberlin',
#   'compart',
#   'hold',
#   'great',
#   'deal',
#   'stuff',
#   'feel',
#   'nearli',
#   'bulki',
#   'one.'],
#  ['classifi',
#   'laptop',
#   'backpack,',
#   "i'm",
#   'find',
#   'use',
#   'all-purpos',
#   'backpack.',
#   'course,',
#   'carri',
#   'laptop',
#   '-',
#   "there'",
#   'compart',
#   'specif',
#   'design',
#   '(17',
#   'less)',
#   '-',
#   'comfort',
#   'use',
#   'gener',
#   'use.th',
#   'back',
#   'sturdy.',
#   'sturdi',
#   'design',
#   'protect',
#   'laptop',
#   'tumbl',
#   'falls,',
#   'love',
#   'reasons:',
#   'first,',
#   'throw',
#   'sort',
#   'junk',
#   'backpack',
#   '(big',
#   'books,',
#   'lunchbox,',
#   'shoes,',
#   'etc.)',
#   'bulg',
#   'back.',
#   'happen',
#   'backpacks,',
#   'caus',
#   'difficult',
#   'carry,',
#   'sturdi',
#   'back',
#   'prevent',
#   'here.',
#   'second,',
#   'comfortable.',
#   'hard',
#   'plastic',
#   'backing,',
#   'rigidli',
#   'padded,',
#   'feel',
#   'like',
#   'help',
#   'postur',
#   'wear',
#   'it.mi',
#   'complaint,',
#   "isn't",
#   'big',
#   'one,',
#   'pocket',
#   'organiz',
#   'compartments.',
#   'bit',
#   'complic',
#   'rememb',
#   'is,',
#   'especi',
#   'lot',
#   'stuff.',
#   'bit',
#   'get',
#   'to,',
#   'however,',
#   "doesn't",
#   'diminish',
#   'fact',
#   'great',
#   'backpack.',
#   'fact',
#   "i'd",
#   'add',
#   'extra',
#   'room',
#   'insid',
#   'backpack',
#   'bonus.',
#   'yes,',
#   'like',
#   'backpack.'],
#  ['pros-',
#   'feel',
#   'light',
#   'weight',
#   'stuf',
#   'fully.',
#   'perfect',
#   'no.',
#   'compartments.con',
#   '-',
#   'poor',
#   'zipper',
#   'quality,',
#   'ouch',
#   'water',
#   'contain',
#   'small.'],
#  ['made.',
#   'sturdy.',
#   'multipl',
#   'compart',
#   'store',
#   'gear.veri',
#   'price',
#   'effect',
#   'compar',
#   'product',
#   "uses.i'l",
#   'hold',
#   'time.'],
#  ["i'm",
#   'lifelong',
#   'backpack',
#   'user,',
#   'start',
#   'ww2',
#   'father',
#   'outfit',
#   'armi',
#   'surplu',
#   'items.',
#   'hi',
#   'ho,',
#   'hi',
#   'ho,',
#   'hike',
#   'go.',
#   'snowshoe.',
#   'oh,',
#   'differ',
#   'world',
#   'then,',
#   "i'm",
#   'say',
#   'better.',
#   'equip',
#   'heavi',
#   'prone',
#   'mildew',
#   "weren't",
#   'careful,',
#   'natur',
#   'fiber',
#   'metal',
#   'fittings.',
#   "hadn't",
#   'heard',
#   'ergonomicsher',
#   'amazonbas',
#   'product',
#   'winner.',
#   'improved,',
#   'contemporari',
#   'version',
#   'old',
#   'militari',
#   'surplu',
#   'accompani',
#   'wood',
#   '-',
#   "i'v",
#   'follow',
#   'lifetim',
#   'upgrades.',
#   'nice',
#   'big',
#   'bag',
#   'lot',
#   'pocket',
#   'zippers.',
#   'like',
#   "today'",
#   'technic',
#   'products,',
#   'tradeoff',
#   'total',
#   'protect',
#   'portability.',
#   'no,',
#   "wouldn't",
#   'throw',
#   'laptop',
#   'insid',
#   'expect',
#   'complet',
#   'protection.',
#   'high',
#   'qualiti',
#   'nylon',
#   'tekki',
#   'fabrics,',
#   'adequ',
#   'pad',
#   'shaped,',
#   'comfort',
#   'pack',
#   'straps,',
#   'handl',
#   'belongs,',
#   'straps,',
#   'buckl',
#   'pocket',
#   'there.',
#   'love',
#   'straps,',
#   'buckl',
#   'pockets.it',
#   'expect',
#   'water',
#   'resistant,',
#   'extend',
#   'use',
#   'rain',
#   'need',
#   'separ',
#   'rain',
#   'cover',
#   'coat',
#   'waterproof',
#   'nylon.',
#   'backpack',
#   'pleas',
#   'look,',
#   'black',
#   'orang',
#   'accent',
#   'nice',
#   'conserv',
#   'shape.',
#   'good',
#   'value,',
#   'discov',
#   'shop',
#   'well-known',
#   'place',
#   'kind',
#   'thing.'],
#  ['zipper',
#   'kept',
#   'come',
#   'apart.',
#   'open',
#   'base',
#   'backpack,',
#   'lost',
#   'item.',
#   'doubl',
#   'check',
#   'solid',
#   'tug'],
#  ['better',
#   'nothing,',
#   'good',
#   'case',
#   'logic:',
#   'els-111',
#   '11',
#   'chromebook/surfac',
#   '3',
#   'sleeve.',
#   'fit',
#   'macair',
#   '11.6',
#   'perfect.',
#   'sleev',
#   'simpli',
#   'neoprene,',
#   'snag',
#   'friction,',
#   "doesn't",
#   'easili',
#   'slide',
#   'in/out',
#   'backpack.',
#   'qualiti',
#   'decent,',
#   'look',
#   'like',
#   'beer',
#   'cozi',
#   '(koozie)',
#   'compar',
#   'case',
#   'logic.',
#   'case',
#   'logic',
#   'neoprene!',
#   'highli',
#   'protective,',
#   'light,',
#   'low',
#   'densiti',
#   'foam',
#   'encas',
#   'canvas.',
#   'durabl',
#   'slide',
#   'backpack',
#   'better.',
#   'case',
#   'logic',
#   'open',
#   'side',
#   'slit',
#   'like',
#   'amazon.(i',
#   'bought',
#   'both,',
#   'tri',
#   'return',
#   'amazonbasics,',
#   'go',
#   'charg',
#   '8.34',
#   'send',
#   'back..',
#   'keep',
#   'it..',
#   "don't",
#   'wast',
#   'time..',
#   "don't",
#   'mistake,',
#   'buy',
#   'case',
#   'logic',
#   'els-111',
#   '11',
#   '(note:',
#   'photo',
#   'case',
#   'logic',
#   'sleeve)'],
#  ['better',
#   'nothing,',
#   'good',
#   'case',
#   'logic:',
#   'els-111',
#   '11',
#   'chromebook/surfac',
#   '3',
#   'sleeve.',
#   'fit',
#   'macair',
#   '11.6',
#   'perfect.',
#   'sleev',
#   'simpli',
#   'neoprene,',
#   'snag',
#   'friction,',
#   "doesn't",
#   'easili',
#   'slide',
#   'in/out',
#   'backpack.',
#   'qualiti',
#   'decent,',
#   'look',
#   'like',
#   'beer',
#   'cozi',
#   '(koozie)',
#   'compar',
#   'case',
#   'logic.',
#   'case',
#   'logic',
#   'neoprene!',
#   'highli',
#   'protective,',
#   'light,',
#   'low',
#   'densiti',
#   'foam',
#   'encas',
#   'canvas.',
#   'durabl',
#   'slide',
#   'backpack',
#   'better.',
#   'case',
#   'logic',
#   'open',
#   'side',
#   'slit',
#   'like',
#   'amazon.(i',
#   'bought',
#   'both,',
#   'tri',
#   'return',
#   'amazonbasics,',
#   'go',
#   'charg',
#   '8.34',
#   'send',
#   'back..',
#   'keep',
#   'it..',
#   "don't",
#   'wast',
#   'time..',
#   "don't",
#   'mistake,',
#   'buy',
#   'case',
#   'logic',
#   'els-111',
#   '11',
#   '(note:',
#   'photo',
#   'case',
#   'logic',
#   'sleeve)'],
#  ['better',
#   'nothing,',
#   'good',
#   'case',
#   'logic:',
#   'els-111',
#   '11',
#   'chromebook/surfac',
#   '3',
#   'sleeve.',
#   'fit',
#   'macair',
#   '11.6',
#   'perfect.',
#   'sleev',
#   'simpli',
#   'neoprene,',
#   'snag',
#   'friction,',
#   "doesn't",
#   'easili',
#   'slide',
#   'in/out',
#   'backpack.',
#   'qualiti',
#   'decent,',
#   'look',
#   'like',
#   'beer',
#   'cozi',
#   '(koozie)',
#   'compar',
#   'case',
#   'logic.',
#   'case',
#   'logic',
#   'neoprene!',
#   'highli',
#   'protective,',
#   'light,',
#   'low',
#   'densiti',
#   'foam',
#   'encas',
#   'canvas.',
#   'durabl',
#   'slide',
#   'backpack',
#   'better.',
#   'case',
#   'logic',
#   'open',
#   'side',
#   'slit',
#   'like',
#   'amazon.(i',
#   'bought',
#   'both,',
#   'tri',
#   'return',
#   'amazonbasics,',
#   'go',
#   'charg',
#   '8.34',
#   'send',
#   'back..',
#   'keep',
#   'it..',
#   "don't",
#   'wast',
#   'time..',
#   "don't",
#   'mistake,',
#   'buy',
#   'case',
#   'logic',
#   'els-111',
#   '11',
#   '(note:',
#   'photo',
#   'case',
#   'logic',
#   'sleeve)'],
#  ['recently,',
#   'spent',
#   'hard',
#   'earn',
#   'money',
#   '13.3',
#   'macbook',
#   'pro',
#   'mid',
#   '2012.',
#   'like',
#   'care',
#   'person',
#   'belongings,',
#   '1000',
#   'piec',
#   'machineri',
#   'exception.',
#   'began',
#   'search',
#   'laptop',
#   'sleeve.',
#   'wander',
#   'local',
#   'gener',
#   'store',
#   '(wal-mart,',
#   'target,',
#   'best',
#   'buy,',
#   'etc.)',
#   'notic',
#   'cheap',
#   'laptop',
#   'sleev',
#   '(a',
#   'cheap',
#   'quality)',
#   'nearli',
#   '16!',
#   'like',
#   'heck',
#   'no!',
#   'jump',
#   '(btw',
#   'best',
#   'shoutout',
#   'hard',
#   'worker',
#   'run',
#   'websit',
#   'service)',
#   'search',
#   'laptop',
#   'sleeve.',
#   'approxim',
#   '9.24',
#   'second',
#   'search',
#   'came',
#   'gem.',
#   'be!',
#   'affordable,',
#   'durable,',
#   'classi',
#   'laptop',
#   'sleev',
#   '10.',
#   'educ',
#   'consum',
#   'start',
#   'read',
#   'reviews.',
#   'came',
#   'said:',
#   'laptop',
#   "didn't",
#   'fit.',
#   'it,',
#   'end,',
#   'built',
#   'let',
#   'down.',
#   'poor',
#   'high-school',
#   'student',
#   'am,',
#   'pocket',
#   'parent',
#   'lunch',
#   'money',
#   'order',
#   'got',
#   'open',
#   'package.',
#   'know',
#   'scene',
#   'star',
#   'war',
#   'darth',
#   'vader',
#   'remov',
#   'mask',
#   "that'",
#   'like,',
#   'shocking,',
#   'beautiful.',
#   'unbox',
#   'immedi',
#   'took',
#   'laptop',
#   'backpack',
#   '(which',
#   'store',
#   'nice',
#   'soft',
#   'tee-shirt',
#   'previou',
#   'sleev',
#   'purchase)',
#   'tri',
#   'slip',
#   'case.',
#   'wow.',
#   'sleev',
#   'fit',
#   'like',
#   'glove.if',
#   '13.3',
#   'macbook',
#   'pro',
#   'mid',
#   '2012,',
#   'highli',
#   'recommend',
#   'product.',
#   'protect',
#   'laptop',
#   'snug.',
#   'sleev',
#   'affordable,',
#   'fashionable,',
#   'durabl',
#   'one.'],
#  ['recently,',
#   'spent',
#   'hard',
#   'earn',
#   'money',
#   '13.3',
#   'macbook',
#   'pro',
#   'mid',
#   '2012.',
#   'like',
#   'care',
#   'person',
#   'belongings,',
#   '1000',
#   'piec',
#   'machineri',
#   'exception.',
#   'began',
#   'search',
#   'laptop',
#   'sleeve.',
#   'wander',
#   'local',
#   'gener',
#   'store',
#   '(wal-mart,',
#   'target,',
#   'best',
#   'buy,',
#   'etc.)',
#   'notic',
#   'cheap',
#   'laptop',
#   'sleev',
#   '(a',
#   'cheap',
#   'quality)',
#   'nearli',
#   '16!',
#   'like',
#   'heck',
#   'no!',
#   'jump',
#   '(btw',
#   'best',
#   'shoutout',
#   'hard',
#   'worker',
#   'run',
#   'websit',
#   'service)',
#   'search',
#   'laptop',
#   'sleeve.',
#   'approxim',
#   '9.24',
#   'second',
#   'search',
#   'came',
#   'gem.',
#   'be!',
#   'affordable,',
#   'durable,',
#   'classi',
#   'laptop',
#   'sleev',
#   '10.',
#   'educ',
#   'consum',
#   'start',
#   'read',
#   'reviews.',
#   'came',
#   'said:',
#   'laptop',
#   "didn't",
#   'fit.',
#   'it,',
#   'end,',
#   'built',
#   'let',
#   'down.',
#   'poor',
#   'high-school',
#   'student',
#   'am,',
#   'pocket',
#   'parent',
#   'lunch',
#   'money',
#   'order',
#   'got',
#   'open',
#   'package.',
#   'know',
#   'scene',
#   'star',
#   'war',
#   'darth',
#   'vader',
#   'remov',
#   'mask',
#   "that'",
#   'like,',
#   'shocking,',
#   'beautiful.',
#   'unbox',
#   'immedi',
#   'took',
#   'laptop',
#   'backpack',
#   '(which',
#   'store',
#   'nice',
#   'soft',
#   'tee-shirt',
#   'previou',
#   'sleev',
#   'purchase)',
#   'tri',
#   'slip',
#   'case.',
#   'wow.',
#   'sleev',
#   'fit',
#   'like',
#   'glove.if',
#   '13.3',
#   'macbook',
#   'pro',
#   'mid',
#   '2012,',
#   'highli',
#   'recommend',
#   'product.',
#   'protect',
#   'laptop',
#   'snug.',
#   'sleev',
#   'affordable,',
#   'fashionable,',
#   'durabl',
#   'one.'],
#  ['recently,',
#   'spent',
#   'hard',
#   'earn',
#   'money',
#   '13.3',
#   'macbook',
#   'pro',
#   'mid',
#   '2012.',
#   'like',
#   'care',
#   'person',
#   'belongings,',
#   '1000',
#   'piec',
#   'machineri',
#   'exception.',
#   'began',
#   'search',
#   'laptop',
#   'sleeve.',
#   'wander',
#   'local',
#   'gener',
#   'store',
#   '(wal-mart,',
#   'target,',
#   'best',
#   'buy,',
#   'etc.)',
#   'notic',
#   'cheap',
#   'laptop',
#   'sleev',
#   '(a',
#   'cheap',
#   'quality)',
#   'nearli',
#   '16!',
#   'like',
#   'heck',
#   'no!',
#   'jump',
#   '(btw',
#   'best',
#   'shoutout',
#   'hard',
#   'worker',
#   'run',
#   'websit',
#   'service)',
#   'search',
#   'laptop',
#   'sleeve.',
#   'approxim',
#   '9.24',
#   'second',
#   'search',
#   'came',
#   'gem.',
#   'be!',
#   'affordable,',
#   'durable,',
#   'classi',
#   'laptop',
#   'sleev',
#   '10.',
#   'educ',
#   'consum',
#   'start',
#   'read',
#   'reviews.',
#   'came',
#   'said:',
#   'laptop',
#   "didn't",
#   'fit.',
#   'it,',
#   'end,',
#   'built',
#   'let',
#   'down.',
#   'poor',
#   'high-school',
#   'student',
#   'am,',
#   'pocket',
#   'parent',
#   'lunch',
#   'money',
#   'order',
#   'got',
#   'open',
#   'package.',
#   'know',
#   'scene',
#   'star',
#   'war',
#   'darth',
#   'vader',
#   'remov',
#   'mask',
#   "that'",
#   'like,',
#   'shocking,',
#   'beautiful.',
#   'unbox',
#   'immedi',
#   'took',
#   'laptop',
#   'backpack',
#   '(which',
#   'store',
#   'nice',
#   'soft',
#   'tee-shirt',
#   'previou',
#   'sleev',
#   'purchase)',
#   'tri',
#   'slip',
#   'case.',
#   'wow.',
#   'sleev',
#   'fit',
#   'like',
#   'glove.if',
#   '13.3',
#   'macbook',
#   'pro',
#   'mid',
#   '2012,',
#   'highli',
#   'recommend',
#   'product.',
#   'protect',
#   'laptop',
#   'snug.',
#   'sleev',
#   'affordable,',
#   'fashionable,',
#   'durabl',
#   'one.'],
#  ['larger',
#   'bought',
#   'christma',
#   'gift...i',
#   'enjoy',
#   'bought',
#   'birthday',
#   'gift.....sturdy,',
#   'stylish,',
#   'pad',
#   'protect',
#   'well.',
#   'good',
#   'buy',
#   'price'],
#  ['price', 'good', 'valu', 'last'],
#  ['hold',
#   'laptop,amp,mini',
#   'extern',
#   'memori',
#   'drive,headphones,3d',
#   'glasses,tablet',
#   'cables,and',
#   '2',
#   'extra',
#   'pocket',
#   'awesome,wel',
#   'product.',
#   'thank',
#   '!'],
#  ['nice',
#   'product',
#   'money.',
#   'use',
#   'week,',
#   'long',
#   'time,',
#   'buy',
#   'again.'],
#  ['purchas',
#   'case',
#   'base',
#   'appear',
#   'qualiti',
#   'shown',
#   'pictur',
#   'details.',
#   'impress',
#   'arrival.',
#   'case',
#   'need.',
#   'separ',
#   'compart',
#   'a/c',
#   'power',
#   'cord.',
#   'pad',
#   'construct',
#   'protect',
#   'notebook',
#   'computer.',
#   'worth',
#   'cent',
#   'paid.',
#   'extrem',
#   'features.'],
#  ['expected,',
#   'price',
#   'low',
#   'expect',
#   'a,',
#   'runner-up,',
#   'type',
#   'bag',
#   'perfect.',
#   'delight'],
#  ['qualiti',
#   'product,',
#   'construct',
#   'durabl',
#   'materials.',
#   'pocket',
#   'laptop',
#   'accessori',
#   'supplies.',
#   'use',
#   'briefcas',
#   'serv',
#   'purpos',
#   'well.',
#   'all,',
#   'great',
#   'valu',
#   'reason',
#   'low',
#   'price.'],
#  ['own',
#   'product',
#   'month',
#   'advertised.',
#   'case',
#   'open',
#   'way.',
#   'comput',
#   'bag',
#   'open',
#   'fully.',
#   'inconveni',
#   'wrestl',
#   'laptop',
#   'tri',
#   'fit',
#   'small',
#   'opening.',
#   'recommend',
#   'spend',
#   'extra',
#   'shekel',
#   'buy',
#   'case',
#   'fulli',
#   'opens.'],
#  ['cheap',
#   "doesn't",
#   'appear',
#   'particularly.',
#   'job',
#   'fine,',
#   'plenti',
#   'pocket',
#   'space,',
#   'prefer',
#   'pack',
#   'style'],
#  ['need',
#   'reason',
#   'laptop',
#   'bag',
#   'got',
#   'this.on',
#   'arriv',
#   'dell',
#   'inspiron',
#   'laptop',
#   'insid',
#   'charger',
#   'went',
#   'pocket.',
#   'insid',
#   'laptop',
#   'slip',
#   'middl',
#   'abl',
#   'ipad',
#   'mayb',
#   'diari',
#   'side.',
#   'slide',
#   'pocket',
#   "laptop.it'",
#   'actual',
#   'surprisingli',
#   'handl',
#   'nice',
#   'comfort',
#   'use/hold.th',
#   'strap',
#   'goe',
#   'nice,',
#   'mayb',
#   'pad',
#   'shoulder',
#   'strap.th',
#   'reason',
#   '4',
#   'star',
#   'think',
#   'case',
#   'pad',
#   'protect',
#   'electr',
#   "device.it'",
#   'nice',
#   'bag',
#   'recommend',
#   'price',
#   'great.'],
#  ['have',
#   'look',
#   'product',
#   'found',
#   'expensive,',
#   'found',
#   'fantast',
#   'price',
#   'pleas'],
#  ['verizon',
#   'technician',
#   'laptop',
#   'case',
#   'perfect',
#   'do!!',
#   'thank',
#   'you!'],
#  ['construct', 'reason', 'priced.'],
#  ['great', 'like'],
#  ['buy', 'bad', 'price', 'worth', '!!'],
#  ['fit', 'well,', 'small', 'outsid', 'insid', 'big,', 'thank'],
#  ['like',
#   'item',
#   'price,qu',
#   'usability.',
#   'ideal',
#   'laptops,',
#   'tablets,paperwork',
#   'sandwiches.it',
#   'come',
#   'carri',
#   'handl',
#   'shoulder',
#   'straps.',
#   'qualiti'],
#  ['love', 'far.', 'problems.'],
#  ['fab',
#   'case',
#   'laptop',
#   'buy',
#   'got',
#   'laptop',
#   'fine',
#   'strong',
#   'plenti',
#   'pocket'],
#  ['bag',
#   'great',
#   'valu',
#   'money,',
#   'give',
#   'want',
#   'carri',
#   'laptop',
#   'accessories.'],
#  ['arriv',
#   'time',
#   'pack',
#   'disappoint',
#   'qualiti',
#   'job',
#   'keep',
#   'dust',
#   'second',
#   'laptop,a',
#   'tight',
#   'fit'],
#  ['western',
#   'digit',
#   'passport',
#   'ultra',
#   '2tb',
#   'usb',
#   '3.0',
#   'portabl',
#   'drive',
#   '2.5',
#   '(laptop',
#   'size)',
#   'extern',
#   'hard',
#   'drive.',
#   'hard',
#   'drive',
#   'case',
#   'plastic',
#   'thin',
#   'pretti',
#   'metal',
#   'sheet',
#   "that'",
#   'aesthet',
#   'protection.',
#   'origin',
#   'bought',
#   'match',
#   'extra-tough',
#   'pod',
#   'like',
#   'wd',
#   'nomad',
#   'rug',
#   'case',
#   'offer',
#   'great',
#   'protection.',
#   'fit',
#   'nomad,',
#   'drive',
#   'stay',
#   'seal',
#   'protect',
#   'case',
#   'usb3',
#   'port',
#   'access',
#   'rubber',
#   'flap',
#   '-',
#   'given',
#   'light-weight',
#   'feel',
#   'wd',
#   'passport',
#   'plastic',
#   'drive',
#   'case',
#   'extra',
#   'protect',
#   'nomad',
#   'reassuring.',
#   "there'",
#   'big',
#   'neg',
#   'neg',
#   'case',
#   'store',
#   'short',
#   '40cm',
#   'usb3',
#   'cabl',
#   '(plu',
#   'nomad',
#   'pod',
#   'hide',
#   'drive',
#   'leds).',
#   'altern',
#   'tri',
#   'cheap',
#   'basic',
#   '2.5',
#   'extern',
#   'hard',
#   'drive',
#   'case.th',
#   'amazonbas',
#   'case',
#   'ruggedised,',
#   'passport',
#   'ultra',
#   'drive',
#   'fit',
#   'case',
#   'perfectly,',
#   'use',
#   'case',
#   'plenti',
#   'space',
#   'store',
#   'usb3',
#   'cabl',
#   '(it',
#   'fit',
#   'net',
#   'pocket',
#   'flap).',
#   'hard',
#   'drive',
#   'held',
#   'strap',
#   'prevent',
#   'drive',
#   'slip',
#   'open',
#   'case.',
#   'laptop',
#   'size',
#   '2.5',
#   'hard',
#   'drive',
#   'extra',
#   'shock',
#   'protect',
#   '3.5',
#   'desktop',
#   'versions,',
#   'design',
#   'portabl',
#   'use,',
#   'amazonbas',
#   'case',
#   'offer',
#   'adequ',
#   'protect',
#   'travel',
#   '(i',
#   'slip',
#   'case',
#   'backpack',
#   'commuting).',
#   'find',
#   "i'm",
#   'case',
#   'prefer',
#   'nomad',
#   'version',
#   'simpli',
#   'far',
#   'conveni',
#   'keep',
#   'tab',
#   "drive'",
#   'usb3',
#   'cable.',
#   'amazonbas',
#   'case',
#   'work',
#   'well,',
#   'made,',
#   'cheap',
#   '7,',
#   '5*',
#   'function',
#   'value.'],
#  ['read',
#   'review',
#   'say',
#   'like',
#   'pictured,',
#   'far',
#   'order',
#   'goes,',
#   'fals',
#   'statement.',
#   'case',
#   'exactli',
#   'like',
#   'one',
#   'offers,',
#   'cheaper',
#   'free',
#   'shipping.',
#   'perfect',
#   'deal.',
#   "can't",
#   'complain.'],
#  ['case',
#   'fit',
#   'wd',
#   'passport',
#   'drive',
#   'perfectli',
#   'room',
#   'usb',
#   'cable.'],
#  ['good', 'littl', 'hard', 'case', 'protect', 'extern', 'hard', 'drive'],
#  ['work', 'intended.', 'safeti', 'hard', 'drive', 'store', 'photos.'],
#  ["isn't", 'picture.'],
#  ['work', 'like', 'usb', 'plug', 'charger.'],
#  ['got',
#   'kindl',
#   '7',
#   'tablet',
#   '.',
#   'excel',
#   'job',
#   'charg',
#   'kindl',
#   'fire',
#   '7',
#   'lot',
#   'faster',
#   'came',
#   'kindl',
#   'fire'],
#  ['best',
#   'kindl',
#   'charger',
#   'ever.',
#   'took',
#   '30',
#   'minut',
#   'kindl',
#   'life.'],
#  ['look',
#   'lost',
#   'charger',
#   'fire',
#   'stick',
#   'final',
#   'found',
#   'best',
#   'buy.',
#   'great',
#   'price',
#   'work',
#   'perfectly!'],
#  ['line',
#   'store',
#   'elder',
#   'women',
#   'tri',
#   'return',
#   'tablet.',
#   'custom',
#   'servic',
#   'rep',
#   'told',
#   'charg',
#   'block',
#   'caus',
#   'damag',
#   'tablet',
#   "wasn't",
#   'cover',
#   'replacement.',
#   'happi',
#   'purchas',
#   'charg',
#   'block',
#   'device.'],
#  ['quickli',
#   'charg',
#   'kindl',
#   'son',
#   'use',
#   'work',
#   'great',
#   'right',
#   'packag'],
#  ['bought',
#   'packag',
#   'said',
#   'fast',
#   'charger',
#   'find',
#   'charg',
#   'normal',
#   'speed...',
#   'disappointing.',
#   "i'm",
#   'pretti',
#   'sure',
#   "i'm",
#   'wrong.',
#   'pretti',
#   'self',
#   'explanatory...',
#   ':/'],
#  ['bought', 'charger', 'kindl', 'voyag', 'great.'],
#  ['product', 'work', 'higher-pr', 'one', 'cell', 'phone', 'company.'],
#  ['bought',
#   'use',
#   'kindl',
#   'voyag',
#   'love',
#   'charg',
#   'kindl',
#   '3',
#   'hour',
#   'batteri',
#   'last',
#   'weeks.'],
#  ['purchased,',
#   'took',
#   'home,',
#   'attach',
#   'cable,plug',
#   'in.',
#   'easi',
#   'use.',
#   'problem',
#   'charger.'],
#  ['charg', 'item', 'extra', 'fast.', 'love', "i'm", 'short', 'time'],
#  ['work', 'great', '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!'],
#  ['wall', 'charger', 'work', 'exactli', 'describ', 'kindl', 'paperwhite.'],
#  ['assum',
#   'item',
#   'cord',
#   'plug.',
#   'assume.',
#   'plug',
#   'only.',
#   'cord',
#   '7"',
#   'kindl',
#   'short',
#   'bought',
#   '4',
#   'foot',
#   'cord',
#   'also.',
#   'shorter',
#   'cord',
#   'charg',
#   'go,',
#   'longer',
#   'cord',
#   'new',
#   'plug',
#   'use',
#   'home.',
#   'satisfi'],
#  ['pretti',
#   'conveni',
#   'cabl',
#   'charg',
#   'kindle,,',
#   'great',
#   'price',
#   'readi',
#   'hand'],
#  ['son',
#   'bought',
#   'wife',
#   'kindl',
#   'paperwhit',
#   'christma',
#   'love',
#   'it!',
#   'charger',
#   'great',
#   'trip',
#   'need',
#   'charg',
#   'vehicl',
#   'visit',
#   'relatives!'],
#  ['bought', 'new', 'kindl', 'longer', 'come', 'chargers.', 'fast', 'phone.'],
#  ['tri',
#   'differ',
#   'charg',
#   'blocks,',
#   'work',
#   'properly.',
#   'plug',
#   'block,',
#   'kindl',
#   'came',
#   'right',
#   'up.'],
#  ['buy/',
#   'work',
#   'year',
#   'need',
#   'replaced.',
#   'warranti',
#   'patienc',
#   'replac',
#   'mail',
#   'forms.'],
#  ['love',
#   'best',
#   'charger',
#   'bought.',
#   'quickli',
#   'charg',
#   'kindl',
#   'cell',
#   'phone.'],
#  ['charger',
#   'improv',
#   'had.',
#   'take',
#   'time',
#   'fulli',
#   'charg',
#   'charg',
#   'last',
#   'longer.'],
#  ['item', 'work', 'well.'],
#  ['found',
#   'immedi',
#   'sked',
#   'staff',
#   'member',
#   'need',
#   'help.',
#   'receiv',
#   'good',
#   'advic',
#   'shown',
#   'similar',
#   'altern',
#   'products.',
#   'bought',
#   'perfect',
#   'wanted.',
#   'price',
#   'reasonable.'],
#  ['hey--it',
#   'works.',
#   'prefer',
#   'batteri',
#   'recharg',
#   'direct',
#   'sourc',
#   'instead',
#   'computer.',
#   'cord',
#   'convenient.'],
#  ['wall',
#   'charger',
#   'convenient.',
#   'wish',
#   'sold',
#   'kindl',
#   'instead',
#   'have',
#   'purchas',
#   'separate.',
#   'like',
#   'standard',
#   'package.',
#   'purchas',
#   'bundl',
#   'order',
#   'includ',
#   'kindle.'],
#  ['great', 'product', 'quickli', 'charg', 'kindle!!!!'],
#  ['good', 'work', 'issues.', 'slim', 'portabl'],
#  ['charg', 'faster', 'regular', 'charger.'],
#  ['problem',
#   'includ',
#   'kindl',
#   'paperwhite.',
#   'way',
#   'charg',
#   'paperwhit',
#   'buy',
#   'charger.',
#   'charg',
#   'port',
#   'paperwhit',
#   'small',
#   'work.',
#   'kindl',
#   'provid',
#   'usb',
#   'cabl',
#   'charg',
#   'computer.',
#   'outlet',
#   'plug',
#   'cheep',
#   'plastic',
#   '(hollow)',
#   'probabl',
#   'break,',
#   'warranty.'],
#  ['suppos', 'to.', 'problem', 'it...'],
#  ['exactli',
#   'needed.',
#   "didn't",
#   'want',
#   'settl',
#   'gener',
#   'brand',
#   'charger.',
#   'thank',
#   'best',
#   'buy',
#   "didn't",
#   'to.'],
#  ['work', 'well,', 'charg', 'book', 'reader', 'quickli', 'easili'],
#  ['purchas',
#   'wall',
#   'charger',
#   'issu',
#   'samsung',
#   'kindl',
#   'chargers.',
#   'far,',
#   'charger',
#   'great.',
#   'devic',
#   'charg',
#   'rapidly.'],
#  ['gave',
#   'charger',
#   'stars,',
#   'great',
#   'job',
#   'charg',
#   'new',
#   'paperwhit',
#   'quickli',
#   'includ',
#   'reader',
#   'sold',
#   'separately.'],
#  ['work', 'good', 'plug', 'kindl', 'fire', 'bought'],
#  ['bought.', 'work', 'great', 'far.', 'sure', 'long', 'last.'],
#  ['replac',
#   'charger',
#   "son'",
#   'kindle,',
#   'work',
#   'great,',
#   'highli',
#   'recommended.'],
#  ['hey',
#   'wall',
#   'charger...hey',
#   'wall',
#   'charger...hey',
#   'wall',
#   'charger...',
#   'fail,',
#   'nough',
#   'said.'],
#  ['travel',
#   'intern',
#   'year',
#   'want',
#   'easi',
#   'way',
#   'charg',
#   'kindl',
#   'fire',
#   'hd.',
#   'design',
#   'system',
#   'great.',
#   'basic',
#   'plug',
#   'cord',
#   'changeabl',
#   'heads.',
#   'easi',
#   'use',
#   'easi',
#   'pack.',
#   'tri',
#   'european',
#   'head',
#   'recent',
#   'norway',
#   'word',
#   'great.',
#   'voltag',
#   'convert',
#   '+',
#   'plug',
#   'adapt',
#   'set',
#   "don't",
#   'work',
#   'norwegian',
#   'outlet',
#   'deep.',
#   'work',
#   'perfectly.',
#   'bought',
#   'set',
#   'u.s.',
#   'plug',
#   'charg',
#   'quickli',
#   'home.',
#   'critic',
#   'countri',
#   "isn't",
#   'print',
#   'plug',
#   'head,',
#   'set',
#   'come',
#   'extens',
#   'list',
#   'head',
#   'need',
#   'countries,',
#   'find',
#   'adequate.',
#   'great',
#   'product.'],
#  ['work',
#   'kindle,',
#   'samsung',
#   'galaxi',
#   'note',
#   'ipod',
#   'touch!!!',
#   'love',
#   'multi-funt',
#   'charger!',
#   "didn't",
#   'need',
#   'intern',
#   'kit',
#   "wasn't",
#   'sure...mayb',
#   'day',
#   'come',
#   'handy.'],
#  ['recent',
#   'went',
#   'countri',
#   'took',
#   'charg',
#   'kit',
#   'me.',
#   'chang',
#   'differ',
#   'plug',
#   'adapt',
#   'extrem',
#   'easy,',
#   'problem',
#   'setup',
#   'charg',
#   'kindle.',
#   'fact',
#   'charger',
#   'includ',
#   'kit',
#   'slightli',
#   'larger',
#   'wattag',
#   'adapt',
#   'came',
#   'fire',
#   'hdx,',
#   'allow',
#   'faster',
#   'charging.',
#   'return',
#   'home,',
#   'attach',
#   '110w',
#   'adapt',
#   'addit',
#   'adapter.',
#   'issu',
#   'item',
#   'better',
#   'includ',
#   'carri',
#   'bag',
#   'adapters.',
#   'yes,',
#   "i'd",
#   'love',
#   'nice',
#   'carri',
#   'case,',
#   "wasn't",
#   'option,',
#   'have',
#   'cloth',
#   'bag',
#   'draw',
#   'string',
#   'prefer',
#   'peopl',
#   'need',
#   'multipl',
#   'adapt',
#   'travel.'],
#  ['abv,',
#   'take',
#   '3',
#   '+',
#   'hour',
#   'fulli',
#   'charge.',
#   'hope',
#   'faster',
#   '(mayb',
#   'hour),',
#   'point',
#   'thought',
#   'got',
#   'lemon.',
#   'peopl',
#   'kind',
#   'answer',
#   'question,',
#   'learn',
#   'expect',
#   'miracles,',
#   'lol.',
#   'apart',
#   'that,',
#   'good',
#   'thing',
#   'come',
#   'cord,',
#   'compact',
#   'enough.'],
#  ['lot',
#   'intern',
#   'travelling,',
#   'bought',
#   'convers',
#   'adapt',
#   'kit',
#   'market.',
#   'best-mad',
#   'versatil',
#   'seen',
#   'charg',
#   'electron',
#   'devices,',
#   'includ',
#   'limit',
#   'kindles.',
#   'power',
#   '9',
#   'watt',
#   'work',
#   'safe',
#   'devic',
#   'micro-b',
#   'usb',
#   'charg',
#   'port.',
#   'non-standard',
#   'devices,',
#   'like',
#   'appl',
#   'product',
#   'older',
#   'electron',
#   'have',
#   'mini-b',
#   'ports,',
#   'long',
#   'appropri',
#   'usb',
#   'cord',
#   'countri',
#   '(the',
#   'standard',
#   'european',
#   'c',
#   'plug',
#   'outlier',
#   'like',
#   'south',
#   'american',
#   'countri',
#   'israel',
#   'plug',
#   'dual',
#   'type).th',
#   'charger',
#   'small',
#   'power',
#   'charger,',
#   'durable,',
#   'compact.',
#   'like',
#   'interchang',
#   'plug',
#   'actual',
#   'form',
#   'charger.',
#   'bad',
#   'tendenc',
#   'leav',
#   'adapt',
#   'wall',
#   'socket',
#   'remov',
#   'charger.',
#   'hotel',
#   'guest',
#   'get',
#   'free',
#   'adapter.thi',
#   'new',
#   'price',
#   '29.99(10',
#   'before).',
#   'make',
#   'good',
#   'value,',
#   'consid',
#   'design',
#   'quality.',
#   'unlik',
#   'standard',
#   'powerfast',
#   'charger',
#   'kindl',
#   'fire,',
#   'kit',
#   'come',
#   'usb',
#   'cord,',
#   'complete.',
#   'ad',
#   'bonu',
#   'adapt',
#   'twist',
#   'direction,',
#   'posit',
#   'usb',
#   'cord',
#   'side,',
#   'bottom.'],
#  ['want',
#   'new',
#   'cord',
#   'kindal',
#   'want',
#   'like',
#   'came',
#   'kindal.',
#   'described.',
#   'white',
#   'like',
#   'original.',
#   'ship',
#   'quickly.',
#   'seldom',
#   'write',
#   'review',
#   'like',
#   'privacy.'],
#  ['exactli',
#   'needed.',
#   'work',
#   'well.',
#   'good',
#   'length',
#   'cord,',
#   'good',
#   'valu',
#   'got',
#   'quickly.'],
#  ['wow!',
#   'charger',
#   'amazing!',
#   'charg',
#   'like',
#   'lightning!',
#   'old',
#   'charger',
#   'hold',
#   'candl',
#   'one.',
#   'usual',
#   'charg',
#   '10',
#   '30',
#   'minutes.',
#   'nice',
#   'length',
#   'cord.',
#   'qualiti',
#   'outstanding!',
#   'recommend',
#   'product',
#   'absolutely!'],
#  ['work',
#   'android',
#   'phone',
#   'recent',
#   'trip',
#   'friend',
#   'forgot',
#   'charger.',
#   'work',
#   'great',
#   'kindl',
#   'fire',
#   '!',
#   'needed!'],
#  ['work', 'great', 'kindle!!!'],
#  ['kindl',
#   'power',
#   'adapt',
#   'wall',
#   'charger',
#   'usb',
#   'cabl',
#   'arriv',
#   'sooner',
#   'expect',
#   'excel',
#   'condition.',
#   'exactli',
#   'look',
#   'for.'],
#  ['exactli', 'needed.', 'knew', 'find', 'ebay.', 'good', 'price', 'too!'],
#  ['thrill',
#   'find',
#   'new',
#   'cord',
#   'old',
#   'kindl',
#   'reader.',
#   ',speed',
#   'ship',
#   'awesom',
#   'qualiti',
#   'great'],
#  ['got',
#   'kindl',
# ...
#   'happi',
#   'upgraded.'],
#  ['have',
#   'model',
#   'kindl',
#   'readers,',
#   'best',
#   'definit',
#   'worth',
#   'extra',
#   'cost.'],
#  ['hold',
#   'kindl',
#   'paperwhit',
#   'brighter,',
#   'evenli',
#   'lit,',
#   'sharper',
#   'faster.',
#   '$200',
#   'push',
#   'price',
#   'littl',
#   'high.',
#   'friend',
#   "wasn't",
#   'look',
#   'buy',
#   'old',
#   'one,',
#   'sure',
#   'paid',
#   'much.'],
#  ['kindl',
#   'great',
#   'read',
#   'books,',
#   'batteri',
#   'power',
#   'pretti',
#   'good.th',
#   'experiment',
#   'browser',
#   'user',
#   'friendly.'],
#  ['newest',
#   'kindl',
#   'eread',
#   '(voyage)',
#   'good',
#   'upgrad',
#   'current',
#   'model.',
#   'new',
#   'hardwar',
#   '&',
#   'come',
#   'softwar',
#   'enhanc',
#   'current',
#   'model.',
#   'however,',
#   'extrem',
#   'reading,',
#   'recommend',
#   'upgrad',
#   'own',
#   'current',
#   'paperwhit',
#   'generation.',
#   'high',
#   'price',
#   'justifi'],
#  ['got',
#   'pre',
#   'teen',
#   'took',
#   'like',
#   'duck',
#   'water.',
#   'great',
#   'size',
#   'easi',
#   'pack'],
#  ['doubt',
#   'spend',
#   'extra',
#   'money',
#   'buy',
#   'voyage...',
#   "don't",
#   'be.',
#   "hadn't",
#   'gift',
#   'like',
#   'spent',
#   'money',
#   'glad',
#   'one.'],
#  ['gener',
#   'minor',
#   'upgrad',
#   'paperwhite,',
#   'best',
#   'e-read',
#   'market.',
#   'x-ray',
#   'unnecessari',
#   'read',
#   'game',
#   'throne',
#   'forgot',
#   'certain',
#   'peopl',
#   'were.',
#   'choic',
#   'swipe',
#   'pinch',
#   'chang',
#   'page',
#   'nice',
#   'too.',
#   'great',
#   'devic',
#   "you'r",
#   'budget',
#   'fine',
#   'version.'],
#  ['fantast',
#   'e-reader.',
#   'batteri',
#   'last',
#   'week',
#   'singl',
#   'charg',
#   '(if',
#   'leav',
#   'wifi',
#   'turn',
#   'off).',
#   'feel',
#   'great',
#   'hands.',
#   'lightweight.'],
#  ['e-read',
#   'make',
#   'read',
#   'ebook',
#   'easi',
#   'eye',
#   'provid',
#   'beauti',
#   'experience.',
#   'product',
#   'feel',
#   'like',
#   'qualiti',
#   'gather',
#   'finger',
#   'print',
#   'mark',
#   'quickli',
#   "doesn't",
#   'case.',
#   'overal',
#   'e-read',
#   'experi',
#   'excel',
#   'light',
#   'color',
#   'come',
#   'pleasantly.'],
#  ['love',
#   'light,',
#   'fast',
#   'respons',
#   'chang',
#   'pages.',
#   'kindl',
#   'voyag',
#   'lite.'],
#  ['best',
#   'e',
#   'reader',
#   '!',
#   'new',
#   'voyag',
#   'better',
#   'paperwhit',
#   'great',
#   '!'],
#  ['wife',
#   "won't",
#   'thing',
#   'down!',
#   "she'",
#   'elder',
#   'poor',
#   'vision',
#   'manag',
#   'read',
#   'this.'],
#  ['favorit',
#   'kindl',
#   'far.',
#   'size',
#   'perfect',
#   'weight',
#   'minimal.',
#   'love',
#   'fact',
#   'lit',
#   "don't",
#   'need',
#   'book',
#   'light.'],
#  ['exceed',
#   'expectation.',
#   'easi',
#   'read,',
#   'book',
#   'load',
#   'store',
#   'eas',
#   '!',
#   'great',
#   'save',
#   'space',
#   'avid',
#   'reader.',
#   'travel',
#   'book',
#   'dont',
#   'worri',
#   'space'],
#  ['kindl', 'great', 'buy,', 'pretti', 'simpl', 'use,', 'convenient.'],
#  ['nook',
#   'glow',
#   'miss',
#   'have',
#   'buttons.',
#   '"squeez',
#   'edge"',
#   'page',
#   'turn',
#   'sold',
#   'me.'],
#  ['fun',
#   'toy',
#   'is!',
#   'easi',
#   'learn',
#   'use,',
#   'need',
#   'help,',
#   'onlin',
#   "user'",
#   'guid',
#   'right',
#   'there.',
#   'purchas',
#   'book',
#   "couldn't",
#   'easier,',
#   "there'",
#   '"hard',
#   'copy"',
#   'dispos',
#   "you'",
#   'done.',
#   'abl',
#   'check',
#   'book',
#   'public',
#   'librari',
#   'littl',
#   'effort.',
#   'low-cost',
#   'no-cost',
#   'books,',
#   'current',
#   'best',
#   'sellers,',
#   "there'",
#   'endless',
#   'number',
#   'choos',
#   'from.',
#   'use',
#   'search',
#   'function',
#   'search',
#   'topic',
#   'title.',
#   'like',
#   'stylu',
#   'pen',
#   'touch',
#   'screen',
#   'that.',
#   'know',
#   'enjoy',
#   'kindl',
#   'voyag',
#   'long',
#   'time.'],
#  ['neighbor', 'one,', 'love', 'bought', 'one.'],
#  ['got', 'relative,', 'like', 'pricey', 'though.'],
#  ['good', 'qualiti', 'product.', 'bout', 'gift', 'friend,', 'love'],
#  ['love',
#   'read',
#   'books....pap',
#   'electron',
#   '(via',
#   'ipad),',
#   'own',
#   'kindle.',
#   'shop',
#   'best',
#   'buy,',
#   'mention',
#   'husband',
#   'want',
#   'tri',
#   'kindle....w',
#   'area',
#   'and,',
#   'returned,',
#   'kindl',
#   'voyag',
#   'basket.',
#   'ok',
#   'try.',
#   'love',
#   'it!',
#   'compact,',
#   'easi',
#   'read',
#   'book',
#   'turn',
#   'page',
#   'swipe',
#   '???',
#   'highli',
#   'recommend',
#   'voyag',
#   'exist',
#   'pend',
#   'kindl',
#   'readers.',
#   'great',
#   'featur',
#   'small',
#   'package!'],
#  ['nook', 'user,', 'change,', 'tri', 'kindle.', 'good.'],
#  ['paperwhite,',
#   'voyag',
#   'definit',
#   'better.',
#   'qualiti',
#   'better,',
#   'screen',
#   'seamless',
#   'edge,',
#   'make',
#   'feel',
#   'premium',
#   'deliv',
#   'comfort',
#   'read',
#   'experience.',
#   'lighter',
#   'paperwhite,',
#   'love',
#   'pressur',
#   'sensor',
#   'chang',
#   'pages.',
#   'overal',
#   'better',
#   'experi',
#   'read',
#   'experi',
#   'paperwhite.'],
#  ['wife',
#   'fire',
#   'tablets.',
#   'major',
#   'flaw.',
#   'visibl',
#   'direct',
#   'sunlight.',
#   'product',
#   'address',
#   'issue.',
#   'paper',
#   'white',
#   'screen',
#   'perfect',
#   'day',
#   'pool'],
#  ['toldpeopl', 'fast', 'pickup.th', 'kindl', 'great', 'always.'],
#  ['gift',
#   'wife',
#   'love',
#   'read.',
#   'kindl',
#   'fire',
#   'enjoy',
#   'wish',
#   'smaller',
#   'lighter',
#   'reader',
#   'good',
#   'readi',
#   'outside.',
#   'found',
#   'voyage.'],
#  ['gift.', 'receiv', 'enjoy', 'upgrad', 'previou', 'kindl'],
#  ['good', 'leisure/read', 'fun.', 'students.'],
#  ['good', 'read', 'white', 'blackscreen', 'small'],
#  ['small', 'light', 'weight,', 'easi', 'read', 'bright', 'light', 'condit'],
#  ['prefer', 'pads,', 'read', 'book'],
#  ['great', 'gifts!!', 'enjoy', 'famili', 'members.'],
#  ['work', 'efficiently,', 'complaint', 'far.', 'make', 'read', 'fun!'],
#  ['gift',
#   'friend,',
#   'love',
#   'that!',
#   'told',
#   'devic',
#   'help',
#   'concentr',
#   'read.'],
#  ['purchas',
#   'voyag',
#   'yesterday.',
#   'look',
#   'like',
#   'scratch',
#   'screen',
#   'today',
#   'contact',
#   'directli',
#   'replac',
#   'voyag',
#   'warente',
#   'need',
#   'bestbuy.',
#   'turn',
#   'food',
#   'scratch',
#   'cancel',
#   'replac',
#   'point',
#   'back',
#   'products!',
#   'think',
#   'worth',
#   '199$',
#   'weird',
#   'screen',
#   'discolor',
#   'appear',
#   'orangeish',
#   'blueish',
#   'certain',
#   'light',
#   'condit',
#   'bare',
#   'noticeable.',
#   'normal',
#   'light',
#   'look',
#   'normal.',
#   'cost',
#   'great',
#   'purchas',
#   'real',
#   'need',
#   'upgrad',
#   'paperwhit',
#   'defens',
#   'voyag',
#   'lighter,',
#   'thinner',
#   'respons',
#   'page',
#   'turn',
#   'button',
#   'seamless.',
#   'mighti',
#   'nice',
#   'product.',
#   'note:',
#   'nook',
#   'glow-light',
#   'plu',
#   'cheaper',
#   'look',
#   'nicer',
#   'great',
#   'feel',
#   'well.',
#   'nook',
#   'glowlight',
#   'plu',
#   'stylish',
#   'copperish',
#   'color',
#   'white',
#   'textur',
#   'front.',
#   'voyag',
#   'attract',
#   'think',
#   'sell',
#   'better',
#   '"',
#   'toned"',
#   'color',
#   'like',
#   'mayb',
#   'white',
#   'color',
#   'side.',
#   'voyag',
#   'faster',
#   'nook',
#   'prettymuch',
#   'features.',
#   'feel',
#   'afford',
#   'product',
#   'stylish.',
#   'best',
#   'buy',
#   'offer',
#   'real',
#   'choic',
#   'case',
#   'kindl',
#   'tablets.',
#   'order',
#   'cover',
#   'ebay.'],
#  ['great', 'contrast', 'batteri', 'life', 'easi', 'user', 'interface.'],
#  ['good',
#   'read',
#   'device.',
#   'price',
#   'drop',
#   '100',
#   'dollar,',
#   'deal.',
#   'need',
#   'buy',
#   'level.'],
#  ['kindl',
#   'voyag',
#   'new',
#   'model',
#   'final',
#   'felt',
#   'good',
#   'replac',
#   'kindle4nt',
#   '(non-touch',
#   'buttons).',
#   'origin',
#   '4t',
#   'paperwhit',
#   'model',
#   'work',
#   'poorli',
#   'me,',
#   'lack',
#   'buttons.',
#   'pressur',
#   'sensit',
#   'edg',
#   'voyag',
#   'work',
#   'great,',
#   'touch',
#   'screen',
#   'function',
#   'work',
#   'better',
#   'model.voyag',
#   '$50',
#   'overpriced,',
#   'ultim',
#   'worth',
#   'money',
#   'move',
#   'older',
#   'button-styl',
#   'kindle.'],
#  ['good', 'screen', 'outdoor', 'nighttim', 'use.', 'lightweight.'],
#  ['love', 'read', 'kindl', 'great.'],
#  ['kindl',
#   'best',
#   'buy',
#   'easier',
#   'read.',
#   'e-reader.',
#   'like',
#   'voyag',
#   '6',
#   'bright',
#   'speed,',
#   'plu',
#   'thelarg',
#   'varieti',
#   'read',
#   'material.',
#   'know',
#   'busi',
#   'ofmak',
#   'money',
#   'get',
#   'purchas',
#   'kindl',
#   'books.',
#   'however,',
#   'havefound',
#   'kindl',
#   'book',
#   'avail',
#   'free',
#   'public',
#   'library.',
#   'will,',
#   'doubt,',
#   'buy',
#   'kindl',
#   'book',
#   'future.',
#   'best',
#   'buyha',
#   'good',
#   'me.',
#   'littl',
#   'problem',
#   'find',
#   'thestor',
#   'well-inform',
#   'product',
#   'final',
#   'got',
#   'wanted.'],
#  ['awesom', 'thank', 'good', 'week', 'good', 'day'],
#  ['great',
#   'altern',
#   'tablet',
#   'reading.',
#   'problem',
#   'tri',
#   'read',
#   '*.pdf',
#   'file',
#   '-',
#   'enlarg',
#   'page',
#   'resiz',
#   'document',
#   'easili',
#   'forward.'],
#  ['want',
#   'simpl',
#   'reader',
#   'east',
#   'transport',
#   'use.',
#   'occasion',
#   'use',
#   'tablet',
#   'read',
#   'want',
#   'light',
#   'weight.',
#   "haven't",
#   'test',
#   'sunlight',
#   'far',
#   'love',
#   'smaller',
#   'size',
#   'simplicity.'],
#  ['voyage,',
#   'worked,',
#   'great',
#   '-',
#   'page',
#   'turn',
#   'read',
#   'experi',
#   'seamless',
#   'ink',
#   'crisp,',
#   'make',
#   'real',
#   'upgrad',
#   'paperwhite.',
#   'said,',
#   'start',
#   'freez',
#   'quickli',
#   'got',
#   'hope',
#   'softwar',
#   'issu',
#   'resolv',
#   'soon',
#   '(and',
#   'price',
#   'earli',
#   'adoption,',
#   'sometimes),',
#   'overall,',
#   "couldn't",
#   'pleas',
#   '(working)',
#   'voyage.'],
#  ['easi',
#   'read',
#   'sunlight.',
#   'like',
#   'adjust',
#   'light',
#   'avail',
#   'make',
#   'easi',
#   'read',
#   'anywhere.'],
#  ['purchas', 'kindl', 'friend', 'absolut', 'enjoy'],
#  ['light,',
#   'easi',
#   'read,',
#   'larg',
#   'capac',
#   'multipl',
#   'way',
#   'turn',
#   'pages.',
#   'say,',
#   'wonder',
#   'reader,',
#   'especi',
#   'florida',
#   'sunlight.',
#   'also,',
#   'iphon',
#   'app',
#   'sync',
#   'readi',
#   'progress',
#   'great',
#   'time',
#   'phone',
#   'kindle.'],
#  ['best',
#   'reader',
#   'ever.',
#   "i'v",
#   'lot',
#   'reader',
#   'like',
#   'paper',
#   'white',
#   '2013,',
#   'kindl',
#   'dx,',
#   'b&n',
#   'nook',
#   'kobo',
#   'aura',
#   'hd',
#   'kindl',
#   'voyage.',
#   'different.th',
#   'featur',
#   'wish',
#   "it'd",
#   'support',
#   'memori',
#   'slot!',
#   'guess',
#   'add',
#   'gener',
#   'kindl',
#   'kindl',
#   'fires...'],
#  ['reader',
#   'great,',
#   'crisp',
#   'display',
#   'excel',
#   'batteri',
#   'life.',
#   'like',
#   'have',
#   'option',
#   'button',
#   'flip',
#   'pages,',
#   'swipe',
#   'requir',
#   'hands,',
#   'button',
#   'easier.'],
#  ['love', 'abil', 'read', 'sunlight,', 'creat', 'files.'],
#  ['voyag',
#   'worth',
#   'extra',
#   'money.',
#   'wonder',
#   'device.',
#   'respons',
#   'easi',
#   'use.',
#   'highli',
#   'recommend!'],
#  ['bought',
#   'easier',
#   'read',
#   'meet',
#   'expectations.',
#   'great',
#   'display',
#   'fidelity.'],
#  ['bought',
#   'christma',
#   'gift.',
#   'daughter',
#   'love',
#   'specif',
#   'like',
#   'screen',
#   'lighting.'],
#  ['qualiti', 'display', 'amaz', '-', 'batteri', 'life', 'fantast'],
#  ['text',
#   'sharp',
#   'paper',
#   'like',
#   'lit',
#   'conditions.',
#   'backlight',
#   'dark',
#   'condit',
#   'paper',
#   'like',
#   'quiet',
#   'use',
#   'wanna',
#   'ditch',
#   'clip',
#   'lights.',
#   'set',
#   'automat',
#   'bright',
#   'level',
#   'manual',
#   'set.',
#   'slim',
#   'lightweight',
#   'case',
#   'appreci',
#   'kindle.',
#   'make',
#   'easi',
#   'hold',
#   'carrying/packing.',
#   'practic',
#   'book',
#   'palm',
#   'hand',
#   'device.',
#   'like',
#   'page',
#   'press',
#   'outer',
#   'press',
#   'button',
#   'page',
#   'turning.',
#   'con',
#   'speedi',
#   'respons',
#   'go',
#   'store,',
#   'fastest',
#   'kindl',
#   'yet.',
#   '80',
#   '100',
#   'dollar',
#   'spent',
#   'paperweight.',
#   'fact',
#   'recommend',
#   'paper',
#   'weight',
#   'come',
#   'price.',
#   'im',
#   'want',
#   'best',
#   'best',
#   'bought',
#   '2',
#   'these.',
#   'love',
#   'gift,',
#   'went',
#   'bought',
#   'one.',
#   'reciev',
#   'gift',
#   'aquir',
#   'major',
#   'browni',
#   'points.',
#   '4',
#   'thumb',
#   'up.',
#   'read',
#   'bed,',
#   'woods,',
#   'road',
#   'like.',
#   'voyag',
#   'intend',
#   'go.',
#   '4.5',
#   'option.'],
#  ['issu', 'whatsoever.', 'work', 'well!', 'best', 'e', 'reader', 'is!'],
#  ['line',
#   'e',
#   'reader',
#   'leader',
#   'e',
#   'readers.',
#   'voyag',
#   'excel',
#   'devic',
#   'versatil',
#   'carri',
#   'trips.',
#   'feel',
#   'premium',
#   'page',
#   'turn',
#   'sensor',
#   'littl',
#   'high.',
#   'hindsight',
#   'paper',
#   'white',
#   'save',
#   'bucks.'],
#  ['light', 'weight,', 'great', 'upgrad', 'paperwhite.', 'love', 'it!'],
#  ['price',
#   'point',
#   'bit',
#   'high',
#   'love',
#   'new',
#   'kindle.',
#   'screen',
#   'beautiful,',
#   'light',
#   'auto-adjust',
#   'dim',
#   'great,',
#   'feel',
#   'sturdi',
#   'hold.',
#   'glad',
#   'upgrad',
#   'form',
#   'nook',
#   '4',
#   'star',
#   'price.'],
#  ['like',
#   'small',
#   'size',
#   'auto',
#   'adjust',
#   'light',
#   'screen.',
#   'old',
#   'kindl',
#   'need',
#   'extern',
#   'light',
#   'read,',
#   'come',
#   'build',
#   'one.'],
#  ['read',
#   'love',
#   'e-reader.',
#   'previous',
#   'nook',
#   'like',
#   'it,',
#   'old',
#   'night',
#   'read',
#   'option.',
#   'voyag',
#   'light',
#   'easi',
#   'hold.',
#   'backlight',
#   'great',
#   'night.',
#   'overal',
#   'happi',
#   'product',
#   'reading.'],
#  ['paperwhit',
#   'need',
#   'upgrade.',
#   'market',
#   'excel',
#   'display',
#   'quick',
#   'page',
#   'turns.',
#   'reason',
#   'buy',
#   'dedic',
#   'e-read',
#   '3',
#   'week',
#   'long',
#   'batteri',
#   'life.',
#   'love'],
#  ['small,',
#   'light',
#   'weight',
#   'batteri',
#   'lasts.',
#   'love',
#   'thing.',
#   'way',
#   'better',
#   'lug',
#   'paperback',
#   'long',
#   'flights.'],
#  ['e-read',
#   'fit',
#   'nice',
#   'librari',
#   'electron',
#   'devices.',
#   'work',
#   'great.'],
#  ['second',
#   'kindl',
#   '(the',
#   'last',
#   'years).',
#   'enjoy',
#   'abil',
#   'read',
#   'dark',
#   'background',
#   'light.',
#   'backlight',
#   'work',
#   'eye',
#   'strain',
#   'tablet',
#   'have.',
#   'touch',
#   'surface,',
#   'find',
#   'littl',
#   'sensit',
#   'accident',
#   'move',
#   'pages.',
#   'page',
#   'turn',
#   'work',
#   'well.',
#   'easier',
#   'travel',
#   'unit',
#   'larg',
#   'book.'],
#  ['second',
#   'kindl',
#   'device.',
#   'enjoy',
#   'read',
#   'lower',
#   'light',
#   'condit',
#   'automat',
#   'adjustment.',
#   'touch',
#   'screen',
#   'nice,',
#   'accident',
#   'pagesif',
#   'finger',
#   'slip.',
#   'issu',
#   'readabl',
#   'light',
#   'conditions.'],
#  ['bought',
#   'wife',
#   'christmas.',
#   'nook',
#   '2',
#   'year',
#   '(bought',
#   'best',
#   'buy',
#   '-',
#   'got',
#   '2',
#   'great',
#   'deal)',
#   "can't",
#   'use',
#   'nook',
#   'read',
#   'sunlight.',
#   'voyag',
#   'smaller,',
#   'lighter',
#   'easier',
#   'use.',
#   'read',
#   'sunlight.',
#   'wish',
#   'featur',
#   'like',
#   '-',
#   'color',
#   'display',
#   'sound.',
#   'wait',
#   'decid',
#   'nook.',
#   'easi',
#   'download',
#   'book',
#   'public',
#   'library.',
#   'tad',
#   'expens',
#   'does.'],
#  ['kindl',
#   'voyag',
#   'best',
#   'e-read',
#   'buy!',
#   'resolut',
#   'absolut',
#   'amazing.',
#   'long',
#   'last',
#   'batteri',
#   'is,',
#   'far,',
#   'best',
#   'feature.'],
#  ['older',
#   'version',
#   'kindl',
#   'e-read',
#   'allow',
#   'download',
#   'book',
#   'go,',
#   'felt',
#   'like',
#   'missing.',
#   'upgrad',
#   'later,',
#   'got',
#   'gift,',
#   'think',
#   'basic',
#   'includ',
#   'missing.',
#   'lightweight',
#   'compact',
#   'easili',
#   'slip',
#   'purs',
#   'use',
#   'hand.',
#   'backlight',
#   "doesn't",
#   'disturb',
#   'sleep',
#   'husband',
#   'creat',
#   'light',
#   'bright',
#   'distracting-',
#   'right',
#   'light',
#   'need',
#   'read',
#   'differ',
#   'ligths.',
#   'self-adjust',
#   'read',
#   'dark',
#   'room',
#   'read',
#   'outsid',
#   'bright',
#   'day.'],
#  ['kindl',
#   'great,',
#   'upgrad',
#   'origin',
#   'kindl',
#   "haven't",
#   'look',
#   'back.i',
#   'think',
#   "paperwhite'",
#   'backlight',
#   'bang',
#   'buck',
#   'upgrad',
#   'though.'],
#  ['love', 'happi', 'purchase.', 'expect', '.'],
#  ['like',
#   'reader..',
#   'easi',
#   'read',
#   'daylight',
#   'glare.',
#   'auto',
#   'backlight',
#   'work',
#   'light',
#   'situations.',
#   'like',
#   'link',
#   'dictionary,',
#   'encyclopedia',
#   'internet',
#   'link',
#   'indigenous.',
#   'reader',
#   'util',
#   'all.'],
#  ['great',
#   'ebook',
#   'reader',
#   'ambient',
#   'light,',
#   'page',
#   'press,',
#   'sharp',
#   'text.',
#   'thin',
#   'light.'],
#  ['best',
#   'ebook',
#   'reader',
#   'market.',
#   'text',
#   'crisp',
#   'love',
#   'backlighting.'],
#  ['excel',
#   'device.',
#   'screen',
#   'impressive.',
#   'happi',
#   'purchase,',
#   'look',
#   'forward',
#   'read',
#   'book',
#   'it!'],
#  ...]

# %%
def stemmer(words):
    new_words = []
    for word in words:
        new_words.append(ps.stem(word))
        
    return new_words

# %%
df['tokens'].apply(stemmer)
# Out:
# 8343        cds!
# 8344       work.
# 8345      boycot
# 8346       cope.
# 8347        box.
#           ...
# 28327       read
# 28328       love
# 28329     price.
# 28330      $100!
# 28331    budget.
# Name: tokens, Length: 13995, dtype: object

# %%
df['tokens']
# Out:
# 8343     [great, case, place!, husband, love, it!!!!, h...
# 8344     [discarding, getting, rid, broken, cd, cases,,...
# 8345                          [dollars, more,, boycotting]
# 8346     [initial, impression, good., material, nicer, ...
# 8347     [pros:, standard, echo., cons:, older, generat...
#                                ...
# 28327    [got, 2, 8, yr, old, twins., 11, yr, old, bett...
# 28328    [bought, niece, christmas, gift.she, 9, years,...
# 28329    [nice, light, internet, browsing,, keeping, em...
# 28330    [tablet, absolutely, want!, watch, tv, shows, ...
# 28331    [ninety, dollars,, expectionations, low,, good...
# Name: tokens, Length: 13995, dtype: object

# %%
# Put in a new column `stems`
df['stems'] = word_list
df['stems']
# Out:
# 8343     [great, case, place!, husband, love, it!!!!, h...
# 8344     [discard, get, rid, broken, cd, cases,, broken...
# 8345                               [dollar, more,, boycot]
# 8346     [initi, impress, good., materi, nicer, shini, ...
# 8347     [pros:, standard, echo., cons:, older, gener, ...
#                                ...
# 28327    [got, 2, 8, yr, old, twins., 11, yr, old, bett...
# 28328    [bought, niec, christma, gift.sh, 9, year, old...
# 28329    [nice, light, internet, browsing,, keep, email...
# 28330    [tablet, absolut, want!, watch, tv, show, movi...
# 28331    [nineti, dollars,, expection, low,, good, tabl...
# Name: stems, Length: 13995, dtype: object

# %%
wc = count(df['stems'])

wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ### Lemmatization
#
# You notice immediately that results are kinda funky - words just oddly chopped off. The Porter algorithm did exactly what it knows to do: chop off endings. Stemming works well in applications where humans don't have to worry about reading the results. Search engines and more broadly information retrieval algorithms use stemming. Why? Because it's fast.
#
# Lemmatization on the other hand is more methodical. The goal is to transform a word into its base form called a lemma. Plural nouns with funky spellings get transformed to singular tense. Verbs are all transformed to the transitive. Nice tidy data for a visualization. :) However, this tidy data can come at computational cost. Spacy does a pretty freaking good job of it though. Let's take a look:

# %%
sent = "This is the start of our NLP adventures. We started here with Spacy. We are starting here with NLP."

nlp = spacy.load("en_core_web_lg")

doc = nlp(sent)

# Lemma Attributes
for token in doc:
    print(token.text, "  ", token.lemma_)
# Out:
# This    this
# is    be
# the    the
# start    start
# of    of
# our    -PRON-
# NLP    NLP
# adventures    adventure
# .    .
# We    -PRON-
# started    start
# here    here
# with    with
# Spacy    Spacy
# .    .
# We    -PRON-
# are    be
# starting    start
# here    here
# with    with
# NLP    NLP
# .    .

# %%
# Wrap it all in a function
def get_lemmas(text):

    lemmas = []
    
    doc = nlp(text)
    
    # Something goes here :P
    for token in doc: 
        if ((token.is_stop == False) and (token.is_punct == False)) and (token.pos_ != 'PRON'):
            lemmas.append(token.lemma_)
    
    return lemmas

# %%
df['lemmas'] = df['reviews.text'].apply(get_lemmas)

# %%
df['lemmas'].head()
# Out:
# 8343    [great, case, place, husband, love, hold, lot,...
# 8344    [discard, get, rid, broken, cd, case, broken, ...
# 8345                            [dollar, boycott, amazon]
# 8346    [initial, impression, good, material, nice, sh...
# 8347    [pro, Standard, Echo, con, old, generation, Ec...
# Name: lemmas, dtype: object

# %%
wc = count(df['lemmas'])
wc_top20 = wc[wc['rank'] <= 20]

squarify.plot(sizes=wc_top20['pct_total'], label=wc_top20['word'], alpha=.8 )
plt.axis('off')
plt.show()

# %% [markdown]
# ## Challenge
#
# You should know how to apply lemmatization with Spacy to a corpus of text.

# %% [markdown]
# # Review
#
# In this module project, you've seen us apply Natural Language Processing techniques (tokenization, stopword removal, and lemmatization) to a corpus of Amazon text reviews. We analyzed those reviews using these techniques and discovered that Amazon customers are generally satisfied with the battery life of Amazon products and generally appear satisfied.
#
# You will apply similar techniques to today's [module project assignment](LS_DS_411_Text_Data_Assignment.ipynb) to analyze coffee shop reviews from yelp. Remember that the techniques of processing the text are just the beginning. There are many ways to slice and dice the data.

# %% [markdown]
# # Sources
#
# * Spacy 101 - https://course.spacy.io
# * NLTK Book - https://www.nltk.org/book/
# * An Introduction to Information Retrieval - https://nlp.stanford.edu/IR-book/pdf/irbookonlinereading.pdf

# %% [markdown]
# ## Advanced Resources & Techniques
# - Named Entity Recognition (NER)
# - Dependcy Trees
# - Generators
# - the major libraries (NLTK, Spacy, Gensim)
